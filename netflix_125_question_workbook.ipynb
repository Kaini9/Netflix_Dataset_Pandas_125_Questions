# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaini9/Netflix_Dataset_Pandas_125_Questions/blob/main/netflix_125_question_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Practice Workbook — Netflix Dataset (125 Questions)
# **Prepared by Ananda Rimal** · Dataset: `netflix_titles.csv`
#
# **Done by Saval Kaini**
#
# **Columns:** `show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description`
#
# **Instructions**
# - Write your answer in the code cell **below each question**
# - Every answer must be pandas code — no manual counting
# - Sections G (GroupBy) and H (Cleaning) may need columns you create along the way — read carefully
#
# | Section | Topic | Questions |
# |---------|-------|-----------|
# | A | First Analysis of Data | 15 |
# | B | Selection with `[]`, `.loc`, `.iloc` | 25 |
# | C | Conditions (with `.loc`) | 20 |
# | D | Sorting | 10 |
# | E | Updating Data | 15 |
# | F | GroupBy | 20 |
# | G | Cleaning | 20 |
# | **Total** | | **125** |

# %% [markdown]
# ## Section A — First Analysis of Data (Q1–Q15)

# %% [markdown]
# #### Q1. Load the dataset into a DataFrame called `df` and display the first 5 rows.

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/NetFlix.csv")

# %%
df.head(3)
# Out:
#   show_id     type       title        director  \
# 0      s1  TV Show          3%             NaN
# 1     s10    Movie        1920    Vikram Bhatt
# 2    s100    Movie  3 Heroines  Iman Brotoseno
#
#                                                 cast    country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...      India  15-Dec-17
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...  Indonesia   5-Jan-19
#
#    release_year rating  duration  \
# 0          2020  TV-MA         4
# 1          2008  TV-MA       143
# 2          2016  TV-PG       124
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...
# 2  Three Indonesian women break records by becomi...

# %% [markdown]
# #### Q2. Display the **last 7 rows** of the DataFrame.

# %%
# Your answer here
df.tail(7)
# Out:
#      show_id     type                      title             director  \
# 7780    s993  TV Show                  Bloodride                  NaN
# 7781    s994    Movie                       Blow            Ted Demme
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7780  Ine Marie Wilmann, Bjørnar Teigen, Emma Spetal...
# 7781  Johnny Depp, Penélope Cruz, Franka Potente, Ra...
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7780                  Norway  13-Mar-20          2020  TV-MA         1
# 7781           United States   1-Oct-19          2001      R       123
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# 7783                   Japan   1-Sep-20          2017  TV-MA         2
# 7784  France, Belgium, Spain  26-Aug-16          2013  NC-17       180
# 7785           United States   8-Mar-19          2013  PG-13        98
# 7786           United States   6-Dec-16          2016  TV-MA        81
#
#                                                 genres  \
# 7780   International TV Shows, TV Horror, TV Mysteries
# 7781                                            Dramas
# 7782                International TV Shows, Reality TV
# 7783              Anime Series, International TV Shows
# 7784  Dramas, Independent Movies, International Movies
# 7785              Comedies, Dramas, Independent Movies
# 7786       Dramas, Independent Movies, Romantic Movies
#
#                                             description
# 7780  The doomed passengers aboard a spectral bus he...
# 7781  Cocaine smuggler George rises from poverty to ...
# 7782  Ten master artists turn up the heat in glassbl...
# 7783  Determined to throw off the curse of being Sat...
# 7784  Determined to fall in love, 15-year-old Adele ...
# 7785  The high life leads to high anxiety for a fash...
# 7786  Two former high school sweethearts unexpectedl...

# %% [markdown]
# #### Q3. How many rows and columns does the dataset have?

# %%
total=df.shape
print("total rows and column:", total)
# Out:
# total rows and column: (7787, 12)

# %% [markdown]
# #### Q4. Display the names of all columns.

# %%
# Your answer here
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %%
df.loc[1,:]
# Out:
# show_id                                                       s10
# type                                                        Movie
# title                                                        1920
# director                                             Vikram Bhatt
# cast            Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# country                                                     India
# date_added                                              15-Dec-17
# release_year                                                 2008
# rating                                                      TV-MA
# duration                                                      143
# genres             Horror Movies, International Movies, Thrillers
# description     An architect and his wife move into a castle t...
# Name: 1, dtype: object

# %% [markdown]
# #### Q5. Use `info()` — which columns have missing values, and what is the data type of each column?

# %%
# Your answer here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %% [markdown]
# #### Q6. Use `describe()` on the numeric columns. What is the minimum and maximum `release_year`?

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
# Your answer here
print(df["release_year"].min(),df["release_year"].max())
# Out:
# 1925 2021

# %% [markdown]
# #### Q7. Use `describe(include="object")` on the text columns. Which value appears most often in the `type` column?

# %%
# Your answer here
df.describe(include="object")
# Out:
#        show_id   type     title                director                cast  \
# count     7787   7787      7787                    5398                7069
# unique    7787      2      7787                    4049                6831
# top       s999  Movie  Blue Jay  Raúl Campos, Jan Suter  David Attenborough
# freq         1   5377         1                      18                  18
#
#               country date_added rating         genres  \
# count            7280       7777   7780           7787
# unique            681       1565     14            492
# top     United States   1-Jan-20  TV-MA  Documentaries
# freq             2555        118   2863            334
#
#                                               description
# count                                                7787
# unique                                               7769
# top     Multiple women report their husbands as missin...
# freq                                                    3

# %%
df["type"].value_counts()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %% [markdown]
# #### Q8. Count the missing values in **every** column with one command.

# %%
# Your answer here
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %% [markdown]
# #### Q9. Which single column has the **most** missing values?

# %%
# Your answer here
df.isnull().sum().idxmax()
# Out:
# 'director'

# %% [markdown]
# #### Q10. How many **unique** values are in the `rating` column? Display them.

# %%
# Your answer here
df["rating"].nunique()
# Out:
# 14

# %%
df["rating"].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %% [markdown]
# #### Q11. Show 5 **random** rows using `sample()`.

# %%
# Your answer here
df.sample(5)
# Out:
#      show_id     type                                  title      director  \
# 3784   s4404  TV Show               Narcoworld: Dope Stories           NaN
# 542    s1487    Movie                          Consequences   Ozan Açıktan
# 2689   s3419  TV Show                        Kitten Rescuers           NaN
# 4036   s4631  TV Show                       Once Upon a Time           NaN
# 5553   s5998    Movie  Taylor Tomlinson: Quarter-Life Crisis  Marcus Raboy
#
#                                                    cast         country  \
# 3784                                                NaN   United States
# 542   Nehir Erdoğan, Tardu Flordun, İlker Kaleli, Se...          Turkey
# 2689                                           Jo Brand  United Kingdom
# 4036  Ruby, Mohamed Farraag, Ahmed Dawood, Sawsan Ba...           Egypt
# 5553                                   Taylor Tomlinson   United States
#
#      date_added  release_year rating  duration  \
# 3784  22-Nov-19          2019  TV-MA         1
# 542   25-Oct-19          2014  TV-MA       106
# 2689   2-Oct-19          2017  TV-14         1
# 4036   9-Dec-20          2019  TV-14         1
# 5553   3-Mar-20          2020  TV-MA        61
#
#                                                  genres  \
# 3784                         Crime TV Shows, Docuseries
# 542             Dramas, International Movies, Thrillers
# 2689  British TV Shows, International TV Shows, Real...
# 4036  International TV Shows, Romantic TV Shows, TV ...
# 5553                                    Stand-Up Comedy
#
#                                             description
# 3784  Ride along as police officers and drug smuggle...
# 542   Secrets bubble to the surface after a sensual ...
# 2689  Cat-crazy host Jo Brand follows vets and anima...
# 4036  Fighting to save his ancestors' mansion from d...
# 5553  She's halfway through her 20s — and she's over...

# %% [markdown]
# #### Q12. What is the memory usage of the DataFrame? (hint: `info()` or `memory_usage()`)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
# Your answer here
df.memory_usage().sum()
# Out:
# np.int64(747684)

# %% [markdown]
# #### Q13. Display the data type of only the `release_year` column.

# %%
# Your answer here
df["release_year"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Q14. Count how many titles are of each `type` using `value_counts()`.

# %%
# Your answer here
df["type"].value_counts()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %% [markdown]
# #### Q15. Check: does the dataset contain any **fully duplicated** rows?

# %%
# Your answer here
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Section B — Selection with `[]`, `.loc`, `.iloc` (Q16–Q40)
# *(Q16–Q30: default 0,1,2,... index · Q31–Q40: after `set_index("show_id")`)*

# %% [markdown]
# #### Q16. Select the `title` column as a **Series**.

# %%
# Your answer here
df["title"]
# Out:
# 0                                              3%
# 1                                            1920
# 2                                      3 Heroines
# 3       Blue Mountain State: The Rise of Thadland
# 4                                  Blue Planet II
#                           ...
# 7782                                   Blown Away
# 7783                                Blue Exorcist
# 7784                    Blue Is the Warmest Color
# 7785                                 Blue Jasmine
# 7786                                     Blue Jay
# Name: title, Length: 7787, dtype: object

# %% [markdown]
# #### Q17. Select the `title` column as a **DataFrame** (hint: double brackets).

# %%
# Your answer here
df[["title"]]
# Out:
#                                           title
# 0                                            3%
# 1                                          1920
# 2                                    3 Heroines
# 3     Blue Mountain State: The Rise of Thadland
# 4                                Blue Planet II
# ...                                         ...
# 7782                                 Blown Away
# 7783                              Blue Exorcist
# 7784                  Blue Is the Warmest Color
# 7785                               Blue Jasmine
# 7786                                   Blue Jay
#
# [7787 rows x 1 columns]

# %% [markdown]
# #### Q18. Select the columns `title`, `type`, and `country` together.

# %%
# Your answer here
df[["title","type","country"]]
# Out:
#                                           title     type  \
# 0                                            3%  TV Show
# 1                                          1920    Movie
# 2                                    3 Heroines    Movie
# 3     Blue Mountain State: The Rise of Thadland    Movie
# 4                                Blue Planet II  TV Show
# ...                                         ...      ...
# 7782                                 Blown Away  TV Show
# 7783                              Blue Exorcist  TV Show
# 7784                  Blue Is the Warmest Color    Movie
# 7785                               Blue Jasmine    Movie
# 7786                                   Blue Jay    Movie
#
#                      country
# 0                     Brazil
# 1                      India
# 2                  Indonesia
# 3              United States
# 4             United Kingdom
# ...                      ...
# 7782                  Canada
# 7783                   Japan
# 7784  France, Belgium, Spain
# 7785           United States
# 7786           United States
#
# [7787 rows x 3 columns]

# %% [markdown]
# #### Q19. Select the first 10 rows using `.iloc`.

# %%
# Your answer here
df.iloc[:10]
# Out:
#   show_id     type                                      title  \
# 0      s1  TV Show                                         3%
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
# 5   s1002    Movie                                  Blue Ruin
# 6   s1003    Movie                                Blue Streak
# 7   s1004    Movie                             Blue Valentine
# 8   s1005    Movie                               BluffMaster!
# 9   s1006    Movie        Blurred Lines: Inside the Art World
#
#            director                                               cast  \
# 0               NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2    Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3      Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4               NaN                                 David Attenborough
# 5   Jeremy Saulnier  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...
# 6      Les Mayfield  Martin Lawrence, Luke Wilson, Peter Greene, Da...
# 7  Derek Cianfrance  Ryan Gosling, Michelle Williams, Faith Wladyka...
# 8       Rohan Sippy  Abhishek Bachchan, Priyanka Chopra, Riteish De...
# 9      Barry Avrich                                                NaN
#
#                   country date_added  release_year rating  duration  \
# 0                  Brazil  14-Aug-20          2020  TV-MA         4
# 1                   India  15-Dec-17          2008  TV-MA       143
# 2               Indonesia   5-Jan-19          2016  TV-PG       124
# 3           United States   1-Mar-16          2016      R        90
# 4          United Kingdom   3-Dec-18          2017   TV-G         1
# 5   United States, France  25-Feb-19          2013      R        90
# 6  Germany, United States   1-Jan-21          1999  PG-13        94
# 7           United States   5-Jul-18          2010      R       112
# 8                   India   8-Jan-21          2005  TV-14       129
# 9                  Canada  31-Dec-17          2017  TV-MA        85
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
# 5                      Independent Movies, Thrillers
# 6                       Action & Adventure, Comedies
# 7        Dramas, Independent Movies, Romantic Movies
# 8    Comedies, International Movies, Romantic Movies
# 9                                      Documentaries
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...
# 2  Three Indonesian women break records by becomi...
# 3  New NFL star Thad buys his old teammates' belo...
# 4  This sequel to the award-winning nature series...
# 5  Bad news from the past unhinges vagabond Dwigh...
# 6  A jewel thief returns to his hiding place afte...
# 7  As Cindy and Dean muddle through their languis...
# 8  When his girlfriend learns the truth about his...
# 9  Artists and industry insiders shed light on th...

# %% [markdown]
# #### Q20. Select rows with labels 10 to 20 using `.loc`. How many rows do you get and why?

# %%
# Your answer here
df.loc[10:20]
# Out:
#    show_id     type                                title  \
# 10   s1007  TV Show                                  BNA
# 11   s1008    Movie               BNK48: Girls Don't Cry
# 12   s1009    Movie               Bo Burnham: Make Happy
# 13    s101    Movie                             3 Idiots
# 14   s1010    Movie                    Bo Burnham: what.
# 15   s1011  TV Show                        Bo on the Go!
# 16   s1012    Movie  Bob Lazar: Area 51 & Flying Saucers
# 17   s1013  TV Show       Bob Ross: Beauty Is Everywhere
# 18   s1014    Movie                  Bob's Broken Sleigh
# 19   s1015    Movie                           Bobbi Jene
# 20   s1016    Movie                Bobbleheads The Movie
#
#                           director  \
# 10                             NaN
# 11      Nawapol Thamrongrattanarit
# 12  Bo Burnham, Christopher Storer
# 13                 Rajkumar Hirani
# 14  Bo Burnham, Christopher Storer
# 15                             NaN
# 16   Jeremy Kenyon Lockyer Corbell
# 17                             NaN
# 18                    Jay Surridge
# 19                     Elvira Lind
# 20                       Kirk Wise
#
#                                                  cast  \
# 10  Sumire Morohoshi, Yoshimasa Hosoya, Maria Naga...
# 11                                                NaN
# 12                                         Bo Burnham
# 13  Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...
# 14                                         Bo Burnham
# 15    Catherine O'Connor, Andrew Sabiston, Jim Fowler
# 16                                       Robert Lazar
# 17                                           Bob Ross
# 18  Cole Howard, Bruce Greenwood, Victor Garber, M...
# 19                                   Bobbi Jene Smith
# 20  Jennifer Coolidge, Karen Fukuhara, Khary Payto...
#
#                                    country date_added  release_year rating  \
# 10                                   Japan  30-Jun-20          2020  TV-14
# 11                                Thailand   1-Mar-19          2018  TV-14
# 12                           United States   3-Jun-16          2016  TV-MA
# 13                                   India   1-Aug-19          2009  PG-13
# 14                           United States   1-Jul-18          2013  TV-MA
# 15                                  Canada  21-Mar-19          2007   TV-Y
# 16                           United States  18-Jun-19          2018  TV-MA
# 17                                     NaN   1-Jun-16          1991   TV-G
# 18                                  Canada  17-Dec-15          2015   TV-G
# 19  Denmark, Sweden, Israel, United States   1-Jun-18          2017  TV-MA
# 20                           United States   8-Dec-20          2020     PG
#
#     duration                                             genres  \
# 10         1               Anime Series, International TV Shows
# 11       108  Documentaries, International Movies, Music & M...
# 12        60                  Music & Musicals, Stand-Up Comedy
# 13       164             Comedies, Dramas, International Movies
# 14        60                                    Stand-Up Comedy
# 15         1                                           Kids' TV
# 16        97                                      Documentaries
# 17         1                                           TV Shows
# 18        47                           Children & Family Movies
# 19        99                                      Documentaries
# 20        83                 Children & Family Movies, Comedies
#
#                                           description
# 10  Morphed into a raccoon beastman, Michiru seeks...
# 11  Members of the Thai idol girl group BNK48 open...
# 12  Combining his trademark wit and self-deprecati...
# 13  While attending one of India's premier college...
# 14  Left brain and right brain duke it out – and u...
# 15  Staying at home doesn't mean sitting still for...
# 16  Decades ago, Bob Lazar blew the whistle on Are...
# 17  "The Joy of Painting" host Bob Ross brings his...
# 18  An overly eager elf improves Santa's sleigh, b...
# 19  This candid profile follows dancer Bobbi Jene ...
# 20  A team of bobbleheads band together to defend ...

# %% [markdown]
# #### Q21. Using `.iloc`, select rows at positions 5 to 14 (10 rows). Compare with Q20 — why is the row count logic different?

# %%
# Your answer here
df.iloc[5:15]
# Out:
#    show_id     type                                title  \
# 5    s1002    Movie                            Blue Ruin
# 6    s1003    Movie                          Blue Streak
# 7    s1004    Movie                       Blue Valentine
# 8    s1005    Movie                         BluffMaster!
# 9    s1006    Movie  Blurred Lines: Inside the Art World
# 10   s1007  TV Show                                  BNA
# 11   s1008    Movie               BNK48: Girls Don't Cry
# 12   s1009    Movie               Bo Burnham: Make Happy
# 13    s101    Movie                             3 Idiots
# 14   s1010    Movie                    Bo Burnham: what.
#
#                           director  \
# 5                  Jeremy Saulnier
# 6                     Les Mayfield
# 7                 Derek Cianfrance
# 8                      Rohan Sippy
# 9                     Barry Avrich
# 10                             NaN
# 11      Nawapol Thamrongrattanarit
# 12  Bo Burnham, Christopher Storer
# 13                 Rajkumar Hirani
# 14  Bo Burnham, Christopher Storer
#
#                                                  cast                 country  \
# 5   Macon Blair, Devin Ratray, Amy Hargreaves, Kev...   United States, France
# 6   Martin Lawrence, Luke Wilson, Peter Greene, Da...  Germany, United States
# 7   Ryan Gosling, Michelle Williams, Faith Wladyka...           United States
# 8   Abhishek Bachchan, Priyanka Chopra, Riteish De...                   India
# 9                                                 NaN                  Canada
# 10  Sumire Morohoshi, Yoshimasa Hosoya, Maria Naga...                   Japan
# 11                                                NaN                Thailand
# 12                                         Bo Burnham           United States
# 13  Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...                   India
# 14                                         Bo Burnham           United States
#
#    date_added  release_year rating  duration  \
# 5   25-Feb-19          2013      R        90
# 6    1-Jan-21          1999  PG-13        94
# 7    5-Jul-18          2010      R       112
# 8    8-Jan-21          2005  TV-14       129
# 9   31-Dec-17          2017  TV-MA        85
# 10  30-Jun-20          2020  TV-14         1
# 11   1-Mar-19          2018  TV-14       108
# 12   3-Jun-16          2016  TV-MA        60
# 13   1-Aug-19          2009  PG-13       164
# 14   1-Jul-18          2013  TV-MA        60
#
#                                                genres  \
# 5                       Independent Movies, Thrillers
# 6                        Action & Adventure, Comedies
# 7         Dramas, Independent Movies, Romantic Movies
# 8     Comedies, International Movies, Romantic Movies
# 9                                       Documentaries
# 10               Anime Series, International TV Shows
# 11  Documentaries, International Movies, Music & M...
# 12                  Music & Musicals, Stand-Up Comedy
# 13             Comedies, Dramas, International Movies
# 14                                    Stand-Up Comedy
#
#                                           description
# 5   Bad news from the past unhinges vagabond Dwigh...
# 6   A jewel thief returns to his hiding place afte...
# 7   As Cindy and Dean muddle through their languis...
# 8   When his girlfriend learns the truth about his...
# 9   Artists and industry insiders shed light on th...
# 10  Morphed into a raccoon beastman, Michiru seeks...
# 11  Members of the Thai idol girl group BNK48 open...
# 12  Combining his trademark wit and self-deprecati...
# 13  While attending one of India's premier college...
# 14  Left brain and right brain duke it out – and u...

# %% [markdown]
# #### Q22. Using `.loc`, select rows 0 to 9 with only the columns `title` and `release_year`.

# %%
# Your answer here
df.loc[0:9,["title","release_year"]]
# Out:
#                                        title  release_year
# 0                                         3%          2020
# 1                                       1920          2008
# 2                                 3 Heroines          2016
# 3  Blue Mountain State: The Rise of Thadland          2016
# 4                             Blue Planet II          2017
# 5                                  Blue Ruin          2013
# 6                                Blue Streak          1999
# 7                             Blue Valentine          2010
# 8                               BluffMaster!          2005
# 9        Blurred Lines: Inside the Art World          2017

# %% [markdown]
# #### Q23. Using `.iloc`, select the first 8 rows and the first 5 columns.

# %%
# Your answer here
df.iloc[:8,:5]
# Out:
#   show_id     type                                      title  \
# 0      s1  TV Show                                         3%
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
# 5   s1002    Movie                                  Blue Ruin
# 6   s1003    Movie                                Blue Streak
# 7   s1004    Movie                             Blue Valentine
#
#            director                                               cast
# 0               NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2    Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3      Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4               NaN                                 David Attenborough
# 5   Jeremy Saulnier  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...
# 6      Les Mayfield  Martin Lawrence, Luke Wilson, Peter Greene, Da...
# 7  Derek Cianfrance  Ryan Gosling, Michelle Williams, Faith Wladyka...

# %% [markdown]
# #### Q24. Using `.iloc`, select the **last row** of the DataFrame.

# %%
# Your answer here
df.iloc[-1]
# Out:
# show_id                                                      s999
# type                                                        Movie
# title                                                    Blue Jay
# director                                             Alex Lehmann
# cast                     Sarah Paulson, Mark Duplass, Clu Gulager
# country                                             United States
# date_added                                               6-Dec-16
# release_year                                                 2016
# rating                                                      TV-MA
# duration                                                       81
# genres                Dramas, Independent Movies, Romantic Movies
# description     Two former high school sweethearts unexpectedl...
# Name: 7786, dtype: object

# %% [markdown]
# #### Q25. Using `.iloc`, select the last 5 rows and the last 2 columns (negative positions).

# %%
# Your answer here
df.iloc[-5:,-2:]
# Out:
#                                                 genres  \
# 7782                International TV Shows, Reality TV
# 7783              Anime Series, International TV Shows
# 7784  Dramas, Independent Movies, International Movies
# 7785              Comedies, Dramas, Independent Movies
# 7786       Dramas, Independent Movies, Romantic Movies
#
#                                             description
# 7782  Ten master artists turn up the heat in glassbl...
# 7783  Determined to throw off the curse of being Sat...
# 7784  Determined to fall in love, 15-year-old Adele ...
# 7785  The high life leads to high anxiety for a fash...
# 7786  Two former high school sweethearts unexpectedl...

# %% [markdown]
# #### Q26. Using `.loc`, get the value of `title` for the row with label 50.

# %%
# Your answer here
df.loc[50,"title"]
# Out:
# 'Bonus Family'

# %% [markdown]
# #### Q27. Using `.iloc`, get the value in row position 100, column position 2. Which column is that?

# %%
# Your answer here
df.iloc[100,2]
# Out:
# 'Breakfast, Lunch & Dinner'

# %%
df.sample(1)
# Out:
#      show_id   type             title    director  \
# 7661    s886  Movie  Bhaji In Problem  Smeep Kang
#
#                                                    cast country date_added  \
# 7661  Gippy Grewal, Gurpreet Guggi, Ragini Khanna, O...   India  19-Sep-20
#
#       release_year rating  duration                          genres  \
# 7661          2013  TV-14       117  Comedies, International Movies
#
#                                             description
# 7661  Married to two women – each unaware of the oth...

# %% [markdown]
# #### Q28. Using `.iloc`, select every 100th row (hint: slicing with a step `::100`).

# %%
# Your answer here
df.iloc[::100]
# Out:
#      show_id     type                        title           director  \
# 0         s1  TV Show                           3%                NaN
# 100    s1089  TV Show    Breakfast, Lunch & Dinner                NaN
# 200    s1179  TV Show                    Caliphate                NaN
# 300    s1269  TV Show                     Chambers                NaN
# 400    s1359    Movie             Christian Mingle     Corbin Bernsen
# ...      ...      ...                          ...                ...
# 7300    s757    Movie                      Barsaat  Rajkumar Santoshi
# 7400    s766    Movie                       Battle   Katarina Launing
# 7500    s775    Movie      Bbuddah Hoga Terra Baap     Puri Jagannadh
# 7600    s830  TV Show                       Ben 10                NaN
# 7700    s920    Movie  Bill Hicks: One Night Stand   John Fortenberry
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 100   David Chang, Seth Rogen, Chrissy Teigen, Lena ...
# 200   Aliette Opheim, Gizem Erdogan, Amed Bozan, Alb...
# 300   Sivan Alyra Rose, Uma Thurman, Tony Goldwyn, M...
# 400   Lacey Chabert, Jonathan Patrick Moore, Saidah ...
# ...                                                 ...
# 7300  Twinkle Khanna, Bobby Deol, Danny Denzongpa, R...
# 7400  Lisa Teige, Fabian Svegaard Tapia, Vebjørn Eng...
# 7500  Amitabh Bachchan, Hema Malini, Raveena Tandon,...
# 7600  Tara Strong, Montse Hernandez, David Kaye, Rog...
# 7700                                         Bill Hicks
#
#                                    country date_added  release_year rating  \
# 0                                   Brazil  14-Aug-20          2020  TV-MA
# 100                          United States  23-Oct-19          2019  TV-MA
# 200                                 Sweden  18-Mar-20          2020  TV-MA
# 300                          United States  26-Apr-19          2019  TV-MA
# 400                          United States   6-Jun-19          2014     PG
# ...                                    ...        ...           ...    ...
# 7300                                 India   1-Apr-18          1995  TV-PG
# 7400  Norway, Denmark, Netherlands, Sweden   1-Dec-18          2018  TV-MA
# 7500                                 India   5-Jul-20          2011  TV-14
# 7600                         United States  30-Sep-18          2016  TV-Y7
# 7700                        United Kingdom  31-Dec-18          1991  TV-MA
#
#       duration                                             genres  \
# 0            4  International TV Shows, TV Dramas, TV Sci-Fi &...
# 100          1                                         Docuseries
# 200          1                  International TV Shows, TV Dramas
# 300          1             TV Horror, TV Mysteries, Teen TV Shows
# 400         99    Comedies, Faith & Spirituality, Romantic Movies
# ...        ...                                                ...
# 7300       166  Action & Adventure, International Movies, Musi...
# 7400        98      Dramas, International Movies, Romantic Movies
# 7500       116               Action & Adventure, Comedies, Dramas
# 7600         1                                           Kids' TV
# 7700        28                                    Stand-Up Comedy
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 100   Chef David Chang takes his insatiable curiosit...
# 200   An impending ISIS attack on Sweden entangles a...
# 300   Haunted by eerie visions and sinister impulses...
# 400   A career woman who has everything but romance ...
# ...                                                 ...
# 7300  A naïve young man and a rich city girl fall in...
# 7400  After Amalie's dad goes bankrupt, the young da...
# 7500  A cooly confident aging hit man returns from e...
# 7600  Ben can transform into ten types of aliens. He...
# 7700  Bill Hicks remembers a wild night in 1989 and ...
#
# [78 rows x 12 columns]

# %% [markdown]
# #### Q29. Using `.loc`, select rows 0 to 4 and **all** columns from `title` to `country` (label slicing on columns!).

# %%
# Your answer here
df.loc[0:4,["title","country"]]
# Out:
#                                        title         country
# 0                                         3%          Brazil
# 1                                       1920           India
# 2                                 3 Heroines       Indonesia
# 3  Blue Mountain State: The Rise of Thadland   United States
# 4                             Blue Planet II  United Kingdom

# %% [markdown]
# #### Q30. Select three specific rows by label — 3, 33, and 333 — in one `.loc` call.

# %%
# Your answer here
df.loc[[3, 33, 333]]
# Out:
#     show_id     type                                      title  \
# 3     s1000    Movie  Blue Mountain State: The Rise of Thadland
# 33    s1028    Movie                                      Bokeh
# 333   s1299  TV Show                                      Cheer
#
#                                director  \
# 3                          Lev L. Spiro
# 33   Geoffrey Orthwein, Andrew Sullivan
# 333                                 NaN
#
#                                                   cast  \
# 3    Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 33   Maika Monroe, Matt O'Leary, Arnar Jónsson, Gun...
# 333                                                NaN
#
#                     country date_added  release_year rating  duration  \
# 3             United States   1-Mar-16          2016      R        90
# 33   United States, Iceland  22-Jun-17          2017  TV-14        92
# 333           United States   8-Jan-20          2020  TV-MA         1
#
#                                            genres  \
# 3                                        Comedies
# 33   Dramas, Independent Movies, Sci-Fi & Fantasy
# 333         Docuseries, Reality TV, Teen TV Shows
#
#                                            description
# 3    New NFL star Thad buys his old teammates' belo...
# 33   After learning they are the sole survivors of ...
# 333  This gripping docuseries follows the ups and d...

# %% [markdown]
# #### Q31. Set `show_id` as the index of `df` (keep it for the rest of Section B). Display the head.

# %%
df.set_index("show_id",inplace=True)
df.head(2)
# Out:
#             type title      director  \
# show_id
# s1       TV Show    3%           NaN
# s10        Movie  1920  Vikram Bhatt
#
#                                                       cast country date_added  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# s10      Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#          release_year rating  duration  \
# show_id
# s1               2020  TV-MA         4
# s10              2008  TV-MA       143
#
#                                                     genres  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s10         Horror Movies, International Movies, Thrillers
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s10      An architect and his wife move into a castle t...

# %% [markdown]
# #### Q32. Using `.loc`, select the row with label `"s1"`.

# %%
# Your answer here
df.loc['s1']
# Out:
# type                                                      TV Show
# title                                                          3%
# director                                                      NaN
# cast            João Miguel, Bianca Comparato, Michel Gomes, R...
# country                                                    Brazil
# date_added                                              14-Aug-20
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                        4
# genres          International TV Shows, TV Dramas, TV Sci-Fi &...
# description     In a future where the elite inhabit an island ...
# Name: s1, dtype: object

# %% [markdown]
# #### Q33. Using `.loc`, select rows `"s10"` to `"s15"`. Does label slicing still include the end?

# %%
# Your answer here
df.loc["s10":"s15"]
# Out:
#             type                                      title          director  \
# show_id
# s10        Movie                                       1920      Vikram Bhatt
# s100       Movie                                 3 Heroines    Iman Brotoseno
# s1000      Movie  Blue Mountain State: The Rise of Thadland      Lev L. Spiro
# s1001    TV Show                             Blue Planet II               NaN
# s1002      Movie                                  Blue Ruin   Jeremy Saulnier
# ...          ...                                        ...               ...
# s1496    TV Show                       Cooked with Cannabis               NaN
# s1497    TV Show                            Cooking on High               NaN
# s1498      Movie                             Cool Hand Luke  Stuart Rosenberg
# s1499      Movie                Cop and a Half: New Recruit     Jon Rosenbaum
# s15        Movie                                       3022        John Suits
#
#                                                       cast  \
# show_id
# s10      Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# s100     Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# s1000    Alan Ritchson, Darin Brooks, James Cade, Rob R...
# s1001                                   David Attenborough
# s1002    Macon Blair, Devin Ratray, Amy Hargreaves, Kev...
# ...                                                    ...
# s1496                                Kelis, Leather Storrs
# s1497                             Josh Leyva, Ngaio Bealum
# s1498    Paul Newman, George Kennedy, J.D. Cannon, Lou ...
# s1499    Lou Diamond Phillips, Lulu Wilson, Giles Panto...
# s15      Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
#
#                        country date_added  release_year rating  duration  \
# show_id
# s10                      India  15-Dec-17          2008  TV-MA       143
# s100                 Indonesia   5-Jan-19          2016  TV-PG       124
# s1000            United States   1-Mar-16          2016      R        90
# s1001           United Kingdom   3-Dec-18          2017   TV-G         1
# s1002    United States, France  25-Feb-19          2013      R        90
# ...                        ...        ...           ...    ...       ...
# s1496            United States  20-Apr-20          2020  TV-MA         1
# s1497            United States  22-Jun-18          2018  TV-MA         1
# s1498            United States   1-Jan-21          1967  TV-14       127
# s1499                   Canada  17-Aug-17          2017     PG        96
# s15              United States  19-Mar-20          2019      R        91
#
#                                                     genres  \
# show_id
# s10         Horror Movies, International Movies, Thrillers
# s100           Dramas, International Movies, Sports Movies
# s1000                                             Comedies
# s1001    British TV Shows, Docuseries, Science & Nature TV
# s1002                        Independent Movies, Thrillers
# ...                                                    ...
# s1496                                           Reality TV
# s1497                                           Reality TV
# s1498                               Classic Movies, Dramas
# s1499                   Children & Family Movies, Comedies
# s15        Independent Movies, Sci-Fi & Fantasy, Thrillers
#
#                                                description
# show_id
# s10      An architect and his wife move into a castle t...
# s100     Three Indonesian women break records by becomi...
# s1000    New NFL star Thad buys his old teammates' belo...
# s1001    This sequel to the award-winning nature series...
# s1002    Bad news from the past unhinges vagabond Dwigh...
# ...                                                    ...
# s1496    Chefs compete to get the hosts and special gue...
# s1497    In the first-ever competitive cannabis cooking...
# s1498    Luke Jackson likes to do things his own way, w...
# s1499    A world-weary detective is forced to team up w...
# s15      Stranded when the Earth is suddenly destroyed ...
#
# [556 rows x 11 columns]

# %% [markdown]
# #### Q34. Using `.iloc`, select the row at position 0. Is it the same row as label `"s1"`?

# %%
# Your answer here
df.iloc[0]
# Out:
# type                                                      TV Show
# title                                                          3%
# director                                                      NaN
# cast            João Miguel, Bianca Comparato, Michel Gomes, R...
# country                                                    Brazil
# date_added                                              14-Aug-20
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                        4
# genres          International TV Shows, TV Dramas, TV Sci-Fi &...
# description     In a future where the elite inhabit an island ...
# Name: s1, dtype: object

# %% [markdown]
# #### Q35. Using `.loc`, get the `title` and `type` of the show with id `"s500"`.

# %%
# Your answer here
df.loc["s500",["title","type"]]
# Out:
# title    Ana e Vitória
# type             Movie
# Name: s500, dtype: object

# %% [markdown]
# #### Q36. Using `.iloc`, select the row at position 499. Is its label `"s500"`? Explain why or why not in a comment.

# %%
# Your answer here
df.iloc[499]
#values may no longer match the row position.
# Out:
# type                                                      TV Show
# title                        Code Geass: Lelouch of the Rebellion
# director                                                      NaN
# cast            Jun Fukuyama, Takahiro Sakurai, Yukana, Ami Ko...
# country                                                     Japan
# date_added                                               1-May-19
# release_year                                                 2008
# rating                                                      TV-MA
# duration                                                        2
# genres                       Anime Series, International TV Shows
# description     A high-schooler who's granted powers to make a...
# Name: s1448, dtype: object

# %% [markdown]
# #### Q37. Using `.loc`, select shows `"s1"`, `"s100"`, and `"s1000"` with columns `title` and `release_year`.

# %%
# Your answer here
df.loc[['s1', 's100', 's1000'], ['title', 'release_year']]
# Out:
#                                              title  release_year
# show_id
# s1                                              3%          2020
# s100                                    3 Heroines          2016
# s1000    Blue Mountain State: The Rise of Thadland          2016

# %% [markdown]
# #### Q38. What happens if you run `df.loc[0]` now? Try it, read the error, and explain in a comment.

# %%
# Your answer here
#because i have set the index to show id so it gets error
try:
    df.loc[0]
except KeyError as e:
    print("KeyError:", e)
# Out:
# KeyError: 0

# %% [markdown]
# #### Q39. Using `.iloc`, select rows at positions [0, 99, 999] in one call.

# %%
# Your answer here
df.iloc[[0, 99, 999]]
# Out:
#             type         title          director  \
# show_id
# s1       TV Show            3%               NaN
# s1088      Movie  Break Up 100    Lawrence Cheng
# s1899      Movie       Dushman  Shagufta Rafique
#
#                                                       cast    country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# s1088    Ekin Cheng, Chrissie Chow, Ivana Wong, Jase Ho...  Hong Kong
# s1899    Kartar Cheema, Jashan Singh, Sakshi Gulati, Gu...        NaN
#
#         date_added  release_year rating  duration  \
# show_id
# s1       14-Aug-20          2020  TV-MA         4
# s1088     1-Dec-18          2014  TV-14       105
# s1899     1-Oct-18          2017  TV-14       141
#
#                                                     genres  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s1088      Comedies, International Movies, Romantic Movies
# s1899                         Dramas, International Movies
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s1088    After their 99th breakup, a career woman and h...
# s1899    An Indian hotel waiter forms an unlikely bond ...

# %% [markdown]
# #### Q40. Reset the index back to 0,1,2,... using `reset_index()`. Display the head.

# %%
# Your answer here
df = df.reset_index()
df.sample(2)
# Out:
#      show_id     type               title                     director  \
# 2321   s3088  TV Show             IZombie                          NaN
# 2332   s3098    Movie  Jack of all Trades  Harvey Glazer, Stuart Stone
#
#                                                    cast        country  \
# 2321  Rose McIver, Malcolm Goodwin, Rahul Kohli, Rob...  United States
# 2332                                                NaN         Canada
#
#      date_added  release_year rating  duration  \
# 2321   9-Aug-19          2019  TV-MA         5
# 2332  16-Jul-19          2018  TV-MA        86
#
#                                  genres  \
# 2321  TV Comedies, TV Dramas, TV Horror
# 2332       Documentaries, Sports Movies
#
#                                             description
# 2321  A medical student-turned-zombie tries to retai...
# 2332  Once upon a time, baseball cards were as much ...

# %% [markdown]
# ## Section C — Conditions with `.loc` (Q41–Q60)
# *Write every filter with `df.loc[condition]` or `df.loc[condition, columns]` style where possible.*

# %%
df.sample(3)
# Out:
#      show_id     type                                        title  \
# 2827   s3543    Movie                                 Last Knights
# 5152   s5636  TV Show                                     Sintonia
# 5697   s6126    Movie  The Best of Rafał Rutkowski Olka Szczęśniak
#
#             director                                               cast  \
# 2827  Kazuaki Kiriya  Clive Owen, Morgan Freeman, Cliff Curtis, Akse...
# 5152             NaN    Christian Malheiros, Jottapê, Bruna Mascarenhas
# 5697             NaN                   Rafał Rutkowski, Olka Szczęśniak
#
#                           country date_added  release_year rating  duration  \
# 2827  United Kingdom, South Korea   1-Aug-19          2015      R       115
# 5152                       Brazil   9-Aug-19          2019  TV-MA         1
# 5697                          NaN  19-Sep-16          2016  TV-MA        63
#
#                                                  genres  \
# 2827                                 Action & Adventure
# 5152  Crime TV Shows, International TV Shows, TV Dramas
# 5697                                    Stand-Up Comedy
#
#                                             description
# 2827  A nobleman who values his people's well-being ...
# 5152  Three teens living in the same São Paulo favel...
# 5697  "Recipe for Life" star Rafał Rutkowski and Com...

# %% [markdown]
# #### Q41. Select all rows where `type` is `"Movie"`.

# %%
# Your answer here
df.loc[df["type"]=="Movie"]
# Out:
#      show_id   type                                      title  \
# 1        s10  Movie                                       1920
# 2       s100  Movie                                 3 Heroines
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 5      s1002  Movie                                  Blue Ruin
# 6      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 7778    s991  Movie                            Blood Will Tell
# 7781    s994  Movie                                       Blow
# 7784    s997  Movie                  Blue Is the Warmest Color
# 7785    s998  Movie                               Blue Jasmine
# 7786    s999  Movie                                   Blue Jay
#
#                         director  \
# 1                   Vikram Bhatt
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...                          ...
# 7778  Miguel Cohan, Miguel Cohan
# 7781                   Ted Demme
# 7784         Abdellatif Kechiche
# 7785                 Woody Allen
# 7786                Alex Lehmann
#
#                                                    cast  \
# 1     Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2     Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3     Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 5     Macon Blair, Devin Ratray, Amy Hargreaves, Kev...
# 6     Martin Lawrence, Luke Wilson, Peter Greene, Da...
# ...                                                 ...
# 7778  Oscar Martínez, Dolores Fonzi, Diego Velázquez...
# 7781  Johnny Depp, Penélope Cruz, Franka Potente, Ra...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                        country date_added  release_year rating  duration  \
# 1                        India  15-Dec-17          2008  TV-MA       143
# 2                    Indonesia   5-Jan-19          2016  TV-PG       124
# 3                United States   1-Mar-16          2016      R        90
# 5        United States, France  25-Feb-19          2013      R        90
# 6       Germany, United States   1-Jan-21          1999  PG-13        94
# ...                        ...        ...           ...    ...       ...
# 7778  Argentina, United States  21-Jun-19          2019  TV-MA       113
# 7781             United States   1-Oct-19          2001      R       123
# 7784    France, Belgium, Spain  26-Aug-16          2013  NC-17       180
# 7785             United States   8-Mar-19          2013  PG-13        98
# 7786             United States   6-Dec-16          2016  TV-MA        81
#
#                                                 genres  \
# 1       Horror Movies, International Movies, Thrillers
# 2          Dramas, International Movies, Sports Movies
# 3                                             Comedies
# 5                        Independent Movies, Thrillers
# 6                         Action & Adventure, Comedies
# ...                                                ...
# 7778  Dramas, Independent Movies, International Movies
# 7781                                            Dramas
# 7784  Dramas, Independent Movies, International Movies
# 7785              Comedies, Dramas, Independent Movies
# 7786       Dramas, Independent Movies, Romantic Movies
#
#                                             description
# 1     An architect and his wife move into a castle t...
# 2     Three Indonesian women break records by becomi...
# 3     New NFL star Thad buys his old teammates' belo...
# 5     Bad news from the past unhinges vagabond Dwigh...
# 6     A jewel thief returns to his hiding place afte...
# ...                                                 ...
# 7778  Family patriarch Elías begins to unravel after...
# 7781  Cocaine smuggler George rises from poverty to ...
# 7784  Determined to fall in love, 15-year-old Adele ...
# 7785  The high life leads to high anxiety for a fash...
# 7786  Two former high school sweethearts unexpectedl...
#
# [5377 rows x 12 columns]

# %% [markdown]
# #### Q42. Select all rows where `type` is `"TV Show"` — show only `title` and `country` using one `.loc` call.

# %%
# Your answer here
df.loc[df["type"]=="TV Show"]
# Out:
#      show_id     type                           title director  \
# 0         s1  TV Show                              3%      NaN
# 4      s1001  TV Show                  Blue Planet II      NaN
# 10     s1007  TV Show                             BNA      NaN
# 15     s1011  TV Show                   Bo on the Go!      NaN
# 17     s1013  TV Show  Bob Ross: Beauty Is Everywhere      NaN
# ...      ...      ...                             ...      ...
# 7777    s990  TV Show                      Blood Pact      NaN
# 7779    s992  TV Show                       Bloodline      NaN
# 7780    s993  TV Show                       Bloodride      NaN
# 7782    s995  TV Show                      Blown Away      NaN
# 7783    s996  TV Show                   Blue Exorcist      NaN
#
#                                                    cast         country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 4                                    David Attenborough  United Kingdom
# 10    Sumire Morohoshi, Yoshimasa Hosoya, Maria Naga...           Japan
# 15      Catherine O'Connor, Andrew Sabiston, Jim Fowler          Canada
# 17                                             Bob Ross             NaN
# ...                                                 ...             ...
# 7777  Guilherme Fontes, Ravel Cabral, Jonathan Haage...          Brazil
# 7779  Kyle Chandler, Ben Mendelsohn, Sissy Spacek, L...   United States
# 7780  Ine Marie Wilmann, Bjørnar Teigen, Emma Spetal...          Norway
# 7782                                                NaN          Canada
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...           Japan
#
#      date_added  release_year rating  duration  \
# 0     14-Aug-20          2020  TV-MA         4
# 4      3-Dec-18          2017   TV-G         1
# 10    30-Jun-20          2020  TV-14         1
# 15    21-Mar-19          2007   TV-Y         1
# 17     1-Jun-16          1991   TV-G         1
# ...         ...           ...    ...       ...
# 7777  10-Oct-18          2018  TV-MA         1
# 7779  26-May-17          2017  TV-MA         3
# 7780  13-Mar-20          2020  TV-MA         1
# 7782  12-Jul-19          2019  TV-14         1
# 7783   1-Sep-20          2017  TV-MA         2
#
#                                                  genres  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 4     British TV Shows, Docuseries, Science & Nature TV
# 10                 Anime Series, International TV Shows
# 15                                             Kids' TV
# 17                                             TV Shows
# ...                                                 ...
# 7777  Crime TV Shows, International TV Shows, TV Dramas
# 7779              TV Dramas, TV Mysteries, TV Thrillers
# 7780    International TV Shows, TV Horror, TV Mysteries
# 7782                 International TV Shows, Reality TV
# 7783               Anime Series, International TV Shows
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 4     This sequel to the award-winning nature series...
# 10    Morphed into a raccoon beastman, Michiru seeks...
# 15    Staying at home doesn't mean sitting still for...
# 17    "The Joy of Painting" host Bob Ross brings his...
# ...                                                 ...
# 7777  An ambitious TV reporter uses risky and ethica...
# 7779  When the black sheep son of a respected family...
# 7780  The doomed passengers aboard a spectral bus he...
# 7782  Ten master artists turn up the heat in glassbl...
# 7783  Determined to throw off the curse of being Sat...
#
# [2410 rows x 12 columns]

# %% [markdown]
# #### Q43. Select all titles released in 2021.

# %%
# Your answer here
df.loc[df["release_year"]==2021,"title"]
# Out:
# 250                                       Carmen Sandiego
# 319                                              Charming
# 397     Chris Rock Total Blackout: The Tamborine Exten...
# 492                                             Cobra Kai
# 574               Crack: Cocaine, Corruption & Conspiracy
# 589                           Creating The Queen's Gambit
# 869                                        Disenchantment
# 962                                   Dream Home Makeover
# 1477                                    Gabby's Dollhouse
# 1860                        Headspace Guide to Meditation
# 1937                                                Hilda
# 1950                               History of Swear Words
# 2245                  Inside the World’s Toughest Prisons
# 3138                                                Lupin
# 3431                   Mighty Little Bheem: Kite Festival
# 3528                                              Monarca
# 3769                                    Nailed It! Mexico
# 3855          Night Stalker: The Hunt for a Serial Killer
# 4125                                     Outside the Wire
# 4407                                  Pretend It’s a City
# 4562    Ratones Paranoicos: The Band that Rocked Argen...
# 5401                                          Stuck Apart
# 5470                                      Surviving Death
# 6087                                 The Idhun Chronicles
# 6302                         The Minimalists: Less Is Now
# 6337                               The Netflix Afterparty
# 6914                        Tribhanga - Tedhi Medhi Crazy
# 7281                            What Happened to Mr. Cha?
# 7301                          What Would Sophia Loren Do?
# 7384                                             Wish You
# 7767                                         Bling Empire
# Name: title, dtype: object

# %% [markdown]
# #### Q44. Select all titles released **before** 2000.

# %%
# Your answer here
df.loc[df["release_year"]<2000, ["release_year","title"]]
# Out:
#       release_year                           title
# 6             1999                     Blue Streak
# 17            1991  Bob Ross: Beauty Is Everywhere
# 21            1973                           Bobby
# 49            1967                Bonnie and Clyde
# 68            1989             300 Miles to Heaven
# ...            ...                             ...
# 7680          1999                       Big Daddy
# 7700          1991     Bill Hicks: One Night Stand
# 7702          1992          Bill Hicks: Relentless
# 7703          1993         Bill Hicks: Revelations
# 7704          1989            Bill Hicks: Sane Man
#
# [449 rows x 2 columns]

# %% [markdown]
# #### Q45. Select all titles released between 2015 and 2020 (inclusive) — two conditions with `&`.

# %%
# Your answer here

df.loc[(df["release_year"]>=2015) & (df["release_year"]<=2020),["title","release_year"]]
# Out:
#                                           title  release_year
# 0                                            3%          2020
# 2                                    3 Heroines          2016
# 3     Blue Mountain State: The Rise of Thadland          2016
# 4                                Blue Planet II          2017
# 9           Blurred Lines: Inside the Art World          2017
# ...                                         ...           ...
# 7779                                  Bloodline          2017
# 7780                                  Bloodride          2020
# 7782                                 Blown Away          2019
# 7783                              Blue Exorcist          2017
# 7786                                   Blue Jay          2016
#
# [5420 rows x 2 columns]

# %% [markdown]
# #### Q46. Select all Movies released after 2019 (two conditions).

# %%
df.sample(2)
# Out:
#      show_id     type                  title director  \
# 2689   s3419  TV Show        Kitten Rescuers      NaN
# 5320   s5788  TV Show  Star Trek: Enterprise      NaN
#
#                                                    cast         country  \
# 2689                                           Jo Brand  United Kingdom
# 5320  Scott Bakula, John Billingsley, Jolene Blalock...   United States
#
#      date_added  release_year rating  duration  \
# 2689   2-Oct-19          2017  TV-14         1
# 5320   1-Oct-17          2004  TV-14         4
#
#                                                  genres  \
# 2689  British TV Shows, International TV Shows, Real...
# 5320  Classic & Cult TV, TV Action & Adventure, TV S...
#
#                                             description
# 2689  Cat-crazy host Jo Brand follows vets and anima...
# 5320  Capt. Archer and his crew explore space and di...

# %%
# Your answer here
df.loc[(df["type"]=="Movie") & (df["release_year"]>2019),["title","release_year"]]
# Out:
#                                                   title  release_year
# 20                                Bobbleheads The Movie          2020
# 79                                             365 Days          2020
# 89    Brave Blue World: Racing to Solve Our Water Cr...          2020
# 90                                           37 Seconds          2020
# 150                                             Bulbbul          2020
# ...                                                 ...           ...
# 7626  Best Wishes, Warmest Regards: A Schitt's Creek...          2020
# 7652  Beyond the Boundary: ICC Women's T20 World Cup...          2020
# 7667                                           Bheeshma          2020
# 7690                       Bigflo & Oli: Hip Hop Frenzy          2020
# 7753                        BLACKPINK: Light Up the Sky          2020
#
# [423 rows x 2 columns]

# %% [markdown]
# #### Q47. Select all titles where `rating` is `"TV-MA"`.

# %%
# Your answer here
df.loc[df["rating"]=="TV-MA","title"]
# Out:
# 0                                        3%
# 1                                      1920
# 9       Blurred Lines: Inside the Art World
# 12                   Bo Burnham: Make Happy
# 14                        Bo Burnham: what.
#                        ...
# 7778                        Blood Will Tell
# 7779                              Bloodline
# 7780                              Bloodride
# 7783                          Blue Exorcist
# 7786                               Blue Jay
# Name: title, Length: 2863, dtype: object

# %% [markdown]
# #### Q48. Select all titles where `rating` is either `"PG"` or `"PG-13"` using `.isin()`.

# %%
# Your answer here
df.loc[df["rating"].isin(["PG","PG-13"]),["title","rating"]]
# Out:
#                        title rating
# 6                Blue Streak  PG-13
# 13                  3 Idiots  PG-13
# 20     Bobbleheads The Movie     PG
# 37                      Bolt     PG
# 76         Boy and the World     PG
# ...                      ...    ...
# 7754          3 Days to Kill  PG-13
# 7755                Blackway  PG-13
# 7768  Blinky Bill: The Movie     PG
# 7776           3 Generations  PG-13
# 7785            Blue Jasmine  PG-13
#
# [633 rows x 2 columns]

# %% [markdown]
# #### Q49. Select all titles where `rating` is **NOT** `"TV-MA"` (hint: `~` or `!=`).

# %%
# Your answer here
df.loc[~(df["rating"]=="TV-MA"),["title","rating"]]
# Out:
#                                           title rating
# 2                                    3 Heroines  TV-PG
# 3     Blue Mountain State: The Rise of Thadland      R
# 4                                Blue Planet II   TV-G
# 5                                     Blue Ruin      R
# 6                                   Blue Streak  PG-13
# ...                                         ...    ...
# 7776                              3 Generations  PG-13
# 7781                                       Blow      R
# 7782                                 Blown Away  TV-14
# 7784                  Blue Is the Warmest Color  NC-17
# 7785                               Blue Jasmine  PG-13
#
# [4924 rows x 2 columns]

# %% [markdown]
# #### Q50. Select all titles where `country` is exactly `"India"`.

# %%
# Your answer here
df.loc[df["country"]=="India",["title","country"]]
# Out:
#              title country
# 1             1920   India
# 8     BluffMaster!   India
# 13        3 Idiots   India
# 21           Bobby   India
# 22    Bobby Jasoos   India
# ...            ...     ...
# 7714      Bioscope   India
# 7726   Bittoo Boss   India
# 7727         Black   India
# 7734  Black Friday   India
# 7774   Blood Money   India
#
# [923 rows x 2 columns]

# %% [markdown]
# #### Q51. Select all titles where `country` **contains** `"India"` (hint: `str.contains`, use `na=False`). Why is the row count different from the previous question?

# %%
# Your answer here
# because previously it was only india but here every thing which contain india along other country
df.loc[df["country"].str.contains("India",na=False),["title","country"]]
# Out:
#                title        country
# 1               1920          India
# 8       BluffMaster!          India
# 13          3 Idiots          India
# 21             Bobby          India
# 22      Bobby Jasoos          India
# ...              ...            ...
# 7715  Bir Baba Hindu  Turkey, India
# 7726     Bittoo Boss          India
# 7727           Black          India
# 7734    Black Friday          India
# 7774     Blood Money          India
#
# [990 rows x 2 columns]

# %% [markdown]
# #### Q52. Select all Movies from the United States — show only `title` and `release_year`.

# %%
# Your answer here
df.loc[(df["type"]=="Movie") & (df["country"]=="United States"),["title","release_year"]]
# Out:
#                                           title  release_year
# 3     Blue Mountain State: The Rise of Thadland          2016
# 7                                Blue Valentine          2010
# 12                       Bo Burnham: Make Happy          2016
# 14                            Bo Burnham: what.          2013
# 16          Bob Lazar: Area 51 & Flying Saucers          2018
# ...                                         ...           ...
# 7762                             Bleed for This          2016
# 7776                              3 Generations          2015
# 7781                                       Blow          2001
# 7785                               Blue Jasmine          2013
# 7786                                   Blue Jay          2016
#
# [1850 rows x 2 columns]

# %% [markdown]
# #### Q53. Select all titles where `director` is missing (hint: `isna()`).

# %%
# Your answer here
df.loc[df["director"].isna(),["director","title"]]
# Out:
#      director                           title
# 0         NaN                              3%
# 4         NaN                  Blue Planet II
# 10        NaN                             BNA
# 15        NaN                   Bo on the Go!
# 17        NaN  Bob Ross: Beauty Is Everywhere
# ...       ...                             ...
# 7777      NaN                      Blood Pact
# 7779      NaN                       Bloodline
# 7780      NaN                       Bloodride
# 7782      NaN                      Blown Away
# 7783      NaN                   Blue Exorcist
#
# [2389 rows x 2 columns]

# %% [markdown]
# #### Q54. Select all titles where `director` is **not** missing.

# %%
df.loc[df["director"].notna(), ["director","title"]]
# Out:
#                         director                                      title
# 1                   Vikram Bhatt                                       1920
# 2                 Iman Brotoseno                                 3 Heroines
# 3                   Lev L. Spiro  Blue Mountain State: The Rise of Thadland
# 5                Jeremy Saulnier                                  Blue Ruin
# 6                   Les Mayfield                                Blue Streak
# ...                          ...                                        ...
# 7778  Miguel Cohan, Miguel Cohan                            Blood Will Tell
# 7781                   Ted Demme                                       Blow
# 7784         Abdellatif Kechiche                  Blue Is the Warmest Color
# 7785                 Woody Allen                               Blue Jasmine
# 7786                Alex Lehmann                                   Blue Jay
#
# [5398 rows x 2 columns]

# %% [markdown]
# #### Q55. Select all TV Shows released in 2020 **or** 2021.

# %%
df.sample(2)
# Out:
#      show_id   type                    title                 director  \
# 7252   s7526  Movie    Welcome Mr. President          Riccardo Milani
# 671    s1602  Movie  Daniel Sosa: Maleducado  Alex Díaz, Marcos Bucay
#
#                                                    cast country date_added  \
# 7252  Claudio Bisio, Kasia Smutniak, Beppe Fiorello,...   Italy   1-Oct-16
# 671                                         Daniel Sosa  Mexico  27-Jun-19
#
#       release_year rating  duration                          genres  \
# 7252          2013  TV-MA        99  Comedies, International Movies
# 671           2019  TV-MA        55                 Stand-Up Comedy
#
#                                             description
# 7252  When frustrated politicians name a historical ...
# 671   In his second stand-up special, Daniel Sosa re...

# %%
# Your answer here
df.loc[(df["release_year"] == 2020) | (df["release_year"] == 2021), ["title", "release_year"]]
# Out:
#                             title  release_year
# 0                              3%          2020
# 10                            BNA          2020
# 20          Bobbleheads The Movie          2020
# 31                BoJack Horseman          2020
# 52                      Bookmarks          2020
# ...                           ...           ...
# 7753  BLACKPINK: Light Up the Sky          2020
# 7767                 Bling Empire          2021
# 7772                Blood & Water          2020
# 7775                Blood of Zeus          2020
# 7780                    Bloodride          2020
#
# [899 rows x 2 columns]

# %% [markdown]
# #### Q56. Select all titles whose `title` starts with the letter `"A"` (hint: `str.startswith`, `na=False`).

# %%
# Your answer here
df.loc[df["title"].str.startswith("A",na=False),["title"]]
# Out:
#                                           title
# 512                                A 2nd Chance
# 523                              A 3 Minute Hug
# 534     A Babysitter's Guide to Monster Hunting
# 545                        A Bad Moms Christmas
# 557                            A Beautiful Life
# ...                                         ...
# 6078                                      Azali
# 6089                                      Azhar
# 6100  Aziz Ansari Live at Madison Square Garden
# 6112                  Aziz Ansari: Buried Alive
# 6123                     Aziz Ansari: RIGHT NOW
#
# [505 rows x 1 columns]

# %% [markdown]
# #### Q57. Select all titles whose `title` contains the word `"Love"`.

# %%
# Your answer here
df.loc[df["title"].str.contains("Love",na=False),["title"]]
# Out:
#                                                  title
# 129                                    Brother in Love
# 219                         Can't Help Falling in Love
# 259               Casablancas: The Man Who Loved Women
# 307                                 Chaotic Love Poems
# 402   Christiane Amanpour: Sex & Love Around the World
# ...                                                ...
# 7407                                World Famous Lover
# 7585                                     Beiimaan Love
# 7614                                Berlin, I Love You
# 7623                                        Best Lover
# 7742                                  Black Money Love
#
# [168 rows x 1 columns]

# %% [markdown]
# #### Q58. Using `.loc` with a condition, show the `title`, `rating`, and `release_year` of all Movies rated `"R"`.

# %%
# Your answer here
df.loc[(df["type"] == "Movie") & (df["rating"] == "R"),["title", "rating", "release_year"]]
# Out:
#                                           title rating  release_year
# 3     Blue Mountain State: The Rise of Thadland      R          2016
# 5                                     Blue Ruin      R          2013
# 7                                Blue Valentine      R          2010
# 49                             Bonnie and Clyde      R          1967
# 57                           30 Minutes or Less      R          2011
# ...                                         ...    ...           ...
# 7748                           Black Snake Moan      R          2007
# 7757                                      Blaze      R          2018
# 7762                             Bleed for This      R          2016
# 7773                               Blood Father      R          2016
# 7781                                       Blow      R          2001
#
# [663 rows x 3 columns]

# %% [markdown]
# #### Q59. Count how many Movies were released after 2015 (condition + `len()` or `.shape`).

# %%
# Your answer here
df.loc[(df["type"] == "Movie")&(df["release_year"] > 2015), "title"].shape[0]
# Out:
# 3125

# %% [markdown]
# #### Q60. Challenge: select all Movies that are from India **or** Nepal and released after 2010 — careful with brackets around the `|` condition!

# %%
# Your answer here
df.loc[(df["type"] == "Movie") & ((df["country"] == "India") | (df["country"] == "Nepal")) & (df["release_year"] > 2010), "title"]
# Out:
# 22        Bobby Jasoos
# 28           Bodyguard
# 29               Bogda
# 40      Bombay Talkies
# 69                Boss
#              ...
# 7712     Bilu Rakkhosh
# 7714          Bioscope
# 7726       Bittoo Boss
# 7727             Black
# 7774       Blood Money
# Name: title, Length: 584, dtype: object

# %% [markdown]
# ## Section D — Sorting (Q61–Q70)

# %% [markdown]
# #### Q61. Sort the DataFrame by `release_year` ascending. Show the head — what are the oldest titles?

# %%
# Your answer here
df.sort_values(by="release_year",ascending=True).head()
# Out:
#      show_id     type                               title  \
# 4298   s4868  TV Show   Pioneers: First Women Filmmakers*
# 4402   s4961    Movie                      Prelude to War
# 5688   s6118    Movie                The Battle of Midway
# 7423   s7680    Movie     WWII: Report from the Aleutians
# 7353   s7617    Movie  Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4298                          NaN                        NaN            NaN
# 4402                  Frank Capra                        NaN  United States
# 5688                    John Ford  Henry Fonda, Jane Darwell  United States
# 7423                  John Huston                        NaN  United States
# 7353  Frank Capra, Anatole Litvak                        NaN  United States
#
#      date_added  release_year rating  duration                         genres  \
# 4298  30-Dec-18          1925  TV-14         1                       TV Shows
# 4402  31-Mar-17          1942  TV-14        52  Classic Movies, Documentaries
# 5688  31-Mar-17          1942  TV-14        18  Classic Movies, Documentaries
# 7423  31-Mar-17          1943  TV-PG        45                  Documentaries
# 7353  31-Mar-17          1943  TV-PG        82                  Documentaries
#
#                                             description
# 4298  This collection restores films from women who ...
# 4402  Frank Capra's documentary chronicles the rise ...
# 5688  Director John Ford captures combat footage of ...
# 7423  Filmmaker John Huston narrates this Oscar-nomi...
# 7353  This installment of Frank Capra's acclaimed do...

# %% [markdown]
# #### Q62. Sort by `release_year` **descending**. Show the 10 newest titles.

# %%
# Your answer here
df.sort_values(by="release_year",ascending=False).head(10)
# Out:
#      show_id     type                               title        director  \
# 6914   s7221    Movie       Tribhanga - Tedhi Medhi Crazy  Renuka Shahane
# 492    s1441  TV Show                           Cobra Kai             NaN
# 6337   s6702  TV Show              The Netflix Afterparty             NaN
# 3431   s4087  TV Show  Mighty Little Bheem: Kite Festival             NaN
# 6302   s6671    Movie        The Minimalists: Less Is Now             NaN
# 869    s1781  TV Show                      Disenchantment             NaN
# 7281   s7552    Movie           What Happened to Mr. Cha?    Kim Dong-kyu
# 3138   s3823  TV Show                               Lupin             NaN
# 7301   s7570    Movie         What Would Sophia Loren Do?   Ross Kauffman
# 3528   s4174  TV Show                             Monarca             NaN
#
#                                                    cast        country  \
# 6914  Kajol, Tanvi Azmi, Mithila Palkar, Kunaal Roy ...            NaN
# 492   Ralph Macchio, William Zabka, Xolo Maridueña, ...  United States
# 6337       David Spade, London Hughes, Fortune Feimster  United States
# 3431       Sumruddhi Shukla, Aranya Kaur, Nishka Raheja          India
# 6302                                                NaN  United States
# 869   Abbi Jacobson, Eric André, Nat Faxon, John DiM...  United States
# 7281           Cha In-pyo, Cho Dal-hwan, Song Jae-ryong    South Korea
# 3138  Omar Sy, Ludivine Sagnier, Clotilde Hesme, Nic...  United States
# 7301        Nancy "Vincenza Careri" Kulik, Sophia Loren  United States
# 3528  Irene Azuela, Juan Manuel Bernal, Osvaldo Bena...         Mexico
#
#      date_added  release_year rating  duration  \
# 6914  15-Jan-21          2021  TV-MA        96
# 492    1-Jan-21          2021  TV-14         3
# 6337   2-Jan-21          2021  TV-MA         1
# 3431   8-Jan-21          2021   TV-Y         1
# 6302   1-Jan-21          2021  TV-14        54
# 869   15-Jan-21          2021  TV-14         3
# 7281   1-Jan-21          2021  TV-MA       102
# 3138   8-Jan-21          2021  TV-MA         1
# 7301  15-Jan-21          2021  TV-14        32
# 3528   1-Jan-21          2021  TV-MA         2
#
#                                                  genres  \
# 6914                       Dramas, International Movies
# 492                    TV Action & Adventure, TV Dramas
# 6337          Stand-Up Comedy & Talk Shows, TV Comedies
# 3431                              Kids' TV, TV Comedies
# 6302                                      Documentaries
# 869   TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 7281                     Comedies, International Movies
# 3138  Crime TV Shows, International TV Shows, TV Act...
# 7301                                      Documentaries
# 3528  International TV Shows, Spanish-Language TV Sh...
#
#                                             description
# 6914  When her estranged mother falls into a coma, a...
# 492   Decades after the tournament that changed thei...
# 6337  Hosts David Spade, Fortune Feimster and London...
# 3431  With winter behind them, Bheem and his townspe...
# 6302  They've built a movement out of minimalism. Lo...
# 869   Princess duties call, but she'd rather be drin...
# 7281  With the peak of his career long behind him, a...
# 3138  Inspired by the adventures of Arsène Lupin, ge...
# 7301  In this delightful short documentary, an Itali...
# 3528  After 20 years, Ana María returns to Mexico an...

# %% [markdown]
# #### Q63. Sort by `title` alphabetically.

# %%
# Your answer here
df.sort_values(by="title",ascending=True)
# Out:
#      show_id     type                          title  \
# 2000     s28    Movie                         #Alive
# 2111     s29    Movie  #AnneFrank - Parallel Stories
# 2445     s32    Movie              #FriendButMarried
# 2556     s33    Movie            #FriendButMarried 2
# 2778     s35    Movie                          #Roxy
# ...      ...      ...                            ...
# 5078    s557  TV Show                       忍者ハットリくん
# 1205   s2083  TV Show                           海的儿子
# 2304   s3072  TV Show                           마녀사냥
# 2146   s2930    Movie                        반드시 잡는다
# 2324   s3090    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2000                       Cho Il
# 2111  Sabina Fedeli, Anna Migotto
# 2445                Rako Prijanto
# 2556                Rako Prijanto
# 2778              Michael Kennedy
# ...                           ...
# 5078                          NaN
# 1205                          NaN
# 2304                          NaN
# 2146                Hong-seon Kim
# 2324                Young Jun Lee
#
#                                                    cast      country  \
# 2000                           Yoo Ah-in, Park Shin-hye  South Korea
# 2111                        Helen Mirren, Gengher Gatti        Italy
# 2445  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 2556  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 2778  Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
# ...                                                 ...          ...
# 5078                                                NaN        Japan
# 1205  Li Nanxing, Christopher Lee, Jesseca Liu, Appl...          NaN
# 2304  Si-kyung Sung, Se-yoon Yoo, Dong-yup Shin, Ji-...  South Korea
# 2146                                      Baek Yoon-sik  South Korea
# 2324  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...          NaN
#
#               date_added  release_year rating  duration  \
# 2000            8-Sep-20          2020  TV-MA        99
# 2111            1-Jul-20          2019  TV-14        95
# 2445           21-May-20          2018   TV-G       102
# 2556           28-Jun-20          2020   TV-G       104
# 2778           10-Apr-19          2018  TV-14       105
# ...                  ...           ...    ...       ...
# 5078   December 23, 2018          2012  TV-Y7         2
# 1205           27-Apr-18          2016  TV-14         1
# 2304           19-Feb-18          2015  TV-MA         1
# 2146           28-Feb-18          2017  TV-MA       110
# 2324            1-Sep-18          2018  TV-Y7        68
#
#                                                  genres  \
# 2000     Horror Movies, International Movies, Thrillers
# 2111                Documentaries, International Movies
# 2445      Dramas, International Movies, Romantic Movies
# 2556      Dramas, International Movies, Romantic Movies
# 2778                          Comedies, Romantic Movies
# ...                                                 ...
# 5078                             Anime Series, Kids' TV
# 1205                  International TV Shows, TV Dramas
# 2304  International TV Shows, Korean TV Shows, Stand...
# 2146            Dramas, International Movies, Thrillers
# 2324                           Children & Family Movies
#
#                                             description
# 2000  As a grisly virus rampages a city, a lone man ...
# 2111  Through her diary, Anne Frank's story is retol...
# 2445  Pining for his high school crush for years, a ...
# 2556  As Ayu and Ditto finally transition from best ...
# 2778  A teenage hacker with a huge nose helps a cool...
# ...                                                 ...
# 5078  Hailing from the mountains of Iga, Kanzo Hatto...
# 1205  Two brothers start a new life in Singapore, wh...
# 2304  Four Korean celebrity men and guest stars of b...
# 2146  After people in his town start turning up dead...
# 2324  Miniforce, a special task force of elite range...
#
# [7787 rows x 12 columns]

# %% [markdown]
# #### Q64. Sort by `release_year` descending AND `title` ascending at the same time (list of columns + list of ascending values).

# %%
# Your answer here
df.sort_values(by=["release_year","title"],ascending=[False,True])
# Out:
#      show_id     type                                              title  \
# 7767    s981  TV Show                                       Bling Empire
# 250    s1223  TV Show                                    Carmen Sandiego
# 319    s1286    Movie                                           Charming
# 397    s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 492    s1441  TV Show                                          Cobra Kai
# ...      ...      ...                                                ...
# 7423   s7680    Movie                    WWII: Report from the Aleutians
# 7353   s7617    Movie                 Why We Fight: The Battle of Russia
# 4402   s4961    Movie                                     Prelude to War
# 5688   s6118    Movie                               The Battle of Midway
# 4298   s4868  TV Show                  Pioneers: First Women Filmmakers*
#
#                          director  \
# 7767                          NaN
# 250                           NaN
# 319                  Ross Venokur
# 397                    Chris Rock
# 492                           NaN
# ...                           ...
# 7423                  John Huston
# 7353  Frank Capra, Anatole Litvak
# 4402                  Frank Capra
# 5688                    John Ford
# 4298                          NaN
#
#                                                    cast  \
# 7767                                                NaN
# 250   Gina Rodriguez, Finn Wolfhard, Abby Trott, Mic...
# 319   Wilmer Valderrama, Demi Lovato, Sia, Nia Varda...
# 397                                          Chris Rock
# 492   Ralph Macchio, William Zabka, Xolo Maridueña, ...
# ...                                                 ...
# 7423                                                NaN
# 7353                                                NaN
# 4402                                                NaN
# 5688                          Henry Fonda, Jane Darwell
# 4298                                                NaN
#
#                                     country date_added  release_year rating  \
# 7767                                    NaN  15-Jan-21          2021  TV-MA
# 250                           United States  15-Jan-21          2021  TV-Y7
# 319   Canada, United States, Cayman Islands   8-Jan-21          2021  TV-Y7
# 397                                     NaN  12-Jan-21          2021  TV-MA
# 492                           United States   1-Jan-21          2021  TV-14
# ...                                     ...        ...           ...    ...
# 7423                          United States  31-Mar-17          1943  TV-PG
# 7353                          United States  31-Mar-17          1943  TV-PG
# 4402                          United States  31-Mar-17          1942  TV-14
# 5688                          United States  31-Mar-17          1942  TV-14
# 4298                                    NaN  30-Dec-18          1925  TV-14
#
#       duration                              genres  \
# 7767         1                          Reality TV
# 250          4              Kids' TV, TV Thrillers
# 319         85  Children & Family Movies, Comedies
# 397         98                     Stand-Up Comedy
# 492          3    TV Action & Adventure, TV Dramas
# ...        ...                                 ...
# 7423        45                       Documentaries
# 7353        82                       Documentaries
# 4402        52       Classic Movies, Documentaries
# 5688        18       Classic Movies, Documentaries
# 4298         1                            TV Shows
#
#                                             description
# 7767  Follow LA's wildly wealthy Asian and Asian Ame...
# 250   A master thief who uses her skills for good, C...
# 319   On the eve of his 21st birthday, an adored pri...
# 397   In this extended cut of his 2018 special, Chri...
# 492   Decades after the tournament that changed thei...
# ...                                                 ...
# 7423  Filmmaker John Huston narrates this Oscar-nomi...
# 7353  This installment of Frank Capra's acclaimed do...
# 4402  Frank Capra's documentary chronicles the rise ...
# 5688  Director John Ford captures combat footage of ...
# 4298  This collection restores films from women who ...
#
# [7787 rows x 12 columns]

# %% [markdown]
# #### Q65. Sort by `rating`, and show only `title` and `rating` in the result.

# %%
# Your answer here
df.sort_values(by="rating",ascending=True)[["title","rating"]]
# Out:
#                                                   title rating
# 1373                                   Forbidden Planet      G
# 6767                                              Balto      G
# 6779                                Balto 2: Wolf Quest      G
# 1283                                Fiddler on the Roof      G
# 6783                     Tini: The New Life of Violetta      G
# ...                                                 ...    ...
# 3042                                    Louis C.K. 2017    NaN
# 3043                              Louis C.K.: Hilarious    NaN
# 3044               Louis C.K.: Live at the Comedy Store    NaN
# 3695                               My Honor Was Loyalty    NaN
# 6444  13TH: A Conversation with Oprah Winfrey & Ava ...    NaN
#
# [7787 rows x 2 columns]

# %% [markdown]
# #### Q66. Sort the **index** using `sort_index()` (useful after filtering).

# %%
# Your answer here
df.sort_index()
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1            Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4                     NaN                                 David Attenborough
# ...                   ...                                                ...
# 7782                  NaN                                                NaN
# 7783                  NaN  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Abdellatif Kechiche  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785          Woody Allen  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786         Alex Lehmann           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 0                     Brazil  14-Aug-20          2020  TV-MA         4
# 1                      India  15-Dec-17          2008  TV-MA       143
# 2                  Indonesia   5-Jan-19          2016  TV-PG       124
# 3              United States   1-Mar-16          2016      R        90
# 4             United Kingdom   3-Dec-18          2017   TV-G         1
# ...                      ...        ...           ...    ...       ...
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# 7783                   Japan   1-Sep-20          2017  TV-MA         2
# 7784  France, Belgium, Spain  26-Aug-16          2013  NC-17       180
# 7785           United States   8-Mar-19          2013  PG-13        98
# 7786           United States   6-Dec-16          2016  TV-MA        81
#
#                                                  genres  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1        Horror Movies, International Movies, Thrillers
# 2           Dramas, International Movies, Sports Movies
# 3                                              Comedies
# 4     British TV Shows, Docuseries, Science & Nature TV
# ...                                                 ...
# 7782                 International TV Shows, Reality TV
# 7783               Anime Series, International TV Shows
# 7784   Dramas, Independent Movies, International Movies
# 7785               Comedies, Dramas, Independent Movies
# 7786        Dramas, Independent Movies, Romantic Movies
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     An architect and his wife move into a castle t...
# 2     Three Indonesian women break records by becomi...
# 3     New NFL star Thad buys his old teammates' belo...
# 4     This sequel to the award-winning nature series...
# ...                                                 ...
# 7782  Ten master artists turn up the heat in glassbl...
# 7783  Determined to throw off the curse of being Sat...
# 7784  Determined to fall in love, 15-year-old Adele ...
# 7785  The high life leads to high anxiety for a fash...
# 7786  Two former high school sweethearts unexpectedl...
#
# [7787 rows x 12 columns]

# %% [markdown]
# #### Q67. Show the 5 oldest Movies (filter first, then sort, then head).

# %%
# Your answer here
df.loc[df["type"]=="Movie"].sort_values(by="release_year",ascending=True).head(5)
# Out:
#      show_id   type                                          title  \
# 4402   s4961  Movie                                 Prelude to War
# 5688   s6118  Movie                           The Battle of Midway
# 7049   s7343  Movie  Undercover: How to Operate Behind Enemy Lines
# 7423   s7680  Movie                WWII: Report from the Aleutians
# 7353   s7617  Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4402                  Frank Capra                        NaN  United States
# 5688                    John Ford  Henry Fonda, Jane Darwell  United States
# 7049                    John Ford                        NaN  United States
# 7423                  John Huston                        NaN  United States
# 7353  Frank Capra, Anatole Litvak                        NaN  United States
#
#      date_added  release_year rating  duration                         genres  \
# 4402  31-Mar-17          1942  TV-14        52  Classic Movies, Documentaries
# 5688  31-Mar-17          1942  TV-14        18  Classic Movies, Documentaries
# 7049  31-Mar-17          1943  TV-PG        61  Classic Movies, Documentaries
# 7423  31-Mar-17          1943  TV-PG        45                  Documentaries
# 7353  31-Mar-17          1943  TV-PG        82                  Documentaries
#
#                                             description
# 4402  Frank Capra's documentary chronicles the rise ...
# 5688  Director John Ford captures combat footage of ...
# 7049  This World War II-era training film dramatizes...
# 7423  Filmmaker John Huston narrates this Oscar-nomi...
# 7353  This installment of Frank Capra's acclaimed do...

# %% [markdown]
# #### Q68. Show the 5 newest TV Shows.

# %%
# Your answer here
df.loc[df["type"]=="TV Show"].sort_values(by="release_year",ascending=False).head(5)
# Out:
#      show_id     type                          title director  \
# 3138   s3823  TV Show                          Lupin      NaN
# 492    s1441  TV Show                      Cobra Kai      NaN
# 1950   s2754  TV Show         History of Swear Words      NaN
# 3528   s4174  TV Show                        Monarca      NaN
# 1860   s2673  TV Show  Headspace Guide to Meditation      NaN
#
#                                                    cast        country  \
# 3138  Omar Sy, Ludivine Sagnier, Clotilde Hesme, Nic...  United States
# 492   Ralph Macchio, William Zabka, Xolo Maridueña, ...  United States
# 1950                                       Nicolas Cage  United States
# 3528  Irene Azuela, Juan Manuel Bernal, Osvaldo Bena...         Mexico
# 1860                                    Andy Puddicombe  United States
#
#      date_added  release_year rating  duration  \
# 3138   8-Jan-21          2021  TV-MA         1
# 492    1-Jan-21          2021  TV-14         3
# 1950   5-Jan-21          2021  TV-MA         1
# 3528   1-Jan-21          2021  TV-MA         2
# 1860   1-Jan-21          2021   TV-G         1
#
#                                                  genres  \
# 3138  Crime TV Shows, International TV Shows, TV Act...
# 492                    TV Action & Adventure, TV Dramas
# 1950                            Docuseries, TV Comedies
# 3528  International TV Shows, Spanish-Language TV Sh...
# 1860                    Docuseries, Science & Nature TV
#
#                                             description
# 3138  Inspired by the adventures of Arsène Lupin, ge...
# 492   Decades after the tournament that changed thei...
# 1950  Nicolas Cage hosts this proudly profane, funny...
# 3528  After 20 years, Ana María returns to Mexico an...
# 1860  Headspace takes a friendly, animated look at t...

# %% [markdown]
# #### Q69. Sort by `country` and put the missing values **first** (hint: `na_position="first"`).

# %%
df.sort_values('country', na_position='first')
# Out:
#      show_id     type                           title  \
# 17     s1013  TV Show  Bob Ross: Beauty Is Everywhere
# 23     s1019  TV Show     Bobby Kennedy for President
# 27     s1022  TV Show       Boca Juniors Confidential
# 54     s1047  TV Show                   Border Patrol
# 86     s1076  TV Show                      Brainchild
# ...      ...      ...                             ...
# 2342   s3106    Movie                         Jackpot
# 7722    s940    Movie                   Bitcoin Heist
# 538    s1483    Movie                Conjuring Spirit
# 1954   s2758    Movie               Hitler - A Career
# 550    s1494    Movie                        Cook Off
#
#                                    director  \
# 17                                      NaN
# 23                              Dawn Porter
# 27                                      NaN
# 54                                      NaN
# 86                                      NaN
# ...                                     ...
# 2342                          Dustin Nguyen
# 7722                               Ham Tran
# 538                             Van M. Pham
# 1954  Joachim Fest, Christian Herrendoerfer
# 550                         Tomas Brickhill
#
#                                                    cast       country  \
# 17                                             Bob Ross           NaN
# 23                                    Robert F. Kennedy           NaN
# 27                                                  NaN           NaN
# 54                                        Timothy Balme           NaN
# 86            Sahana Srinivasan, Alie Ward, Ben Seidman           NaN
# ...                                                 ...           ...
# 2342        Chi Tai, Lan Ngoc, Dustin Nguyen, Thu Trang       Vietnam
# 7722  Kate Nhung, Thanh Pham, Petey Majik Nguyen, Su...       Vietnam
# 538   Phuong Mai, Quang Su, Hoang Phuc Nguyen, Chi P...       Vietnam
# 1954                                                NaN  West Germany
# 550   Tendaiishe Chitima, Tendai Nguni, Jesese Mungo...      Zimbabwe
#
#      date_added  release_year rating  duration  \
# 17     1-Jun-16          1991   TV-G         1
# 23    27-Apr-18          2018  TV-MA         1
# 27    14-Sep-18          2018  TV-PG         1
# 54     2-Oct-19          2016  TV-PG         1
# 86     2-Nov-18          2018   TV-G         1
# ...         ...           ...    ...       ...
# 2342   6-Oct-18          2015  TV-14        92
# 7722   2-Sep-17          2016  TV-14       116
# 538   28-Aug-18          2014  TV-MA       112
# 1954  10-Feb-17          1977  TV-MA       150
# 550    1-Jun-20          2017   TV-G       100
#
#                                                  genres  \
# 17                                             TV Shows
# 23                                           Docuseries
# 27    Docuseries, International TV Shows, Spanish-La...
# 54                                           Reality TV
# 86                                             Kids' TV
# ...                                                 ...
# 2342             Comedies, Dramas, International Movies
# 7722  Action & Adventure, Comedies, International Mo...
# 538      Horror Movies, International Movies, Thrillers
# 1954                Documentaries, International Movies
# 550     Comedies, International Movies, Romantic Movies
#
#                                             description
# 17    "The Joy of Painting" host Bob Ross brings his...
# 23    Historic footage and leading voices of the era...
# 27    Players, fans and staff of soccer powerhouse B...
# 54    This reality TV series follows the men and wom...
# 86    From germs and emotions to social media and mo...
# ...                                                 ...
# 2342  A lottery ticket salesperson faces an ethical ...
# 7722  A unconventional, efficient Interpol special a...
# 538   In the wake of her husband's betrayal, a novel...
# 1954  This documentary examines how Adolf Hitler's t...
# 550   Yearning for a better life, a single mother wi...
#
# [7787 rows x 12 columns]

# %% [markdown]
# #### Q70. What does `ascending=[False, True]` mean when sorting by two columns? Demonstrate with `release_year` and `title` and explain in a comment.

# %%
# Your answer here
df.sort_values(['release_year', 'title'], ascending=[False, True])
# Out:
#      show_id     type                                              title  \
# 7767    s981  TV Show                                       Bling Empire
# 250    s1223  TV Show                                    Carmen Sandiego
# 319    s1286    Movie                                           Charming
# 397    s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 492    s1441  TV Show                                          Cobra Kai
# ...      ...      ...                                                ...
# 7423   s7680    Movie                    WWII: Report from the Aleutians
# 7353   s7617    Movie                 Why We Fight: The Battle of Russia
# 4402   s4961    Movie                                     Prelude to War
# 5688   s6118    Movie                               The Battle of Midway
# 4298   s4868  TV Show                  Pioneers: First Women Filmmakers*
#
#                          director  \
# 7767                          NaN
# 250                           NaN
# 319                  Ross Venokur
# 397                    Chris Rock
# 492                           NaN
# ...                           ...
# 7423                  John Huston
# 7353  Frank Capra, Anatole Litvak
# 4402                  Frank Capra
# 5688                    John Ford
# 4298                          NaN
#
#                                                    cast  \
# 7767                                                NaN
# 250   Gina Rodriguez, Finn Wolfhard, Abby Trott, Mic...
# 319   Wilmer Valderrama, Demi Lovato, Sia, Nia Varda...
# 397                                          Chris Rock
# 492   Ralph Macchio, William Zabka, Xolo Maridueña, ...
# ...                                                 ...
# 7423                                                NaN
# 7353                                                NaN
# 4402                                                NaN
# 5688                          Henry Fonda, Jane Darwell
# 4298                                                NaN
#
#                                     country date_added  release_year rating  \
# 7767                                    NaN  15-Jan-21          2021  TV-MA
# 250                           United States  15-Jan-21          2021  TV-Y7
# 319   Canada, United States, Cayman Islands   8-Jan-21          2021  TV-Y7
# 397                                     NaN  12-Jan-21          2021  TV-MA
# 492                           United States   1-Jan-21          2021  TV-14
# ...                                     ...        ...           ...    ...
# 7423                          United States  31-Mar-17          1943  TV-PG
# 7353                          United States  31-Mar-17          1943  TV-PG
# 4402                          United States  31-Mar-17          1942  TV-14
# 5688                          United States  31-Mar-17          1942  TV-14
# 4298                                    NaN  30-Dec-18          1925  TV-14
#
#       duration                              genres  \
# 7767         1                          Reality TV
# 250          4              Kids' TV, TV Thrillers
# 319         85  Children & Family Movies, Comedies
# 397         98                     Stand-Up Comedy
# 492          3    TV Action & Adventure, TV Dramas
# ...        ...                                 ...
# 7423        45                       Documentaries
# 7353        82                       Documentaries
# 4402        52       Classic Movies, Documentaries
# 5688        18       Classic Movies, Documentaries
# 4298         1                            TV Shows
#
#                                             description
# 7767  Follow LA's wildly wealthy Asian and Asian Ame...
# 250   A master thief who uses her skills for good, C...
# 319   On the eve of his 21st birthday, an adored pri...
# 397   In this extended cut of his 2018 special, Chri...
# 492   Decades after the tournament that changed thei...
# ...                                                 ...
# 7423  Filmmaker John Huston narrates this Oscar-nomi...
# 7353  This installment of Frank Capra's acclaimed do...
# 4402  Frank Capra's documentary chronicles the rise ...
# 5688  Director John Ford captures combat footage of ...
# 4298  This collection restores films from women who ...
#
# [7787 rows x 12 columns]

# %% [markdown]
# ## Section E — Updating Data (Q71–Q85)

# %% [markdown]
# #### Q71. Rename the column `listed_in` to `genres` (keep this change).

# %%
# Your answer here
#its already genres so
df = df.rename(columns={'listed_in': 'genres'})
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %% [markdown]
# #### Q72. Create a new column `age_years` = 2026 minus `release_year`.

# %%
# Your answer here
df['age_years'] = 2026 - df['release_year']

# %%
df.loc[:,"age_years"]
# Out:
# 0        6
# 1       18
# 2       10
# 3       10
# 4        9
#         ..
# 7782     7
# 7783     9
# 7784    13
# 7785    13
# 7786    10
# Name: age_years, Length: 7787, dtype: int64

# %% [markdown]
# #### Q73. Create a column `is_movie` that is `True` when `type` is `"Movie"`.

# %%
# Your answer here
df['is_movie'] = df['type'] == 'Movie'

# %%
df.loc[:,"is_movie"]
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784     True
# 7785     True
# 7786     True
# Name: is_movie, Length: 7787, dtype: bool

# %% [markdown]
# #### Q74. Create a column `is_recent` that is `True` when `release_year >= 2020`.

# %%
# Your answer here
df['is_recent'] = df['release_year'] >= 2020

# %%
df.loc[:,"is_recent"]
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Name: is_recent, Length: 7787, dtype: bool

# %% [markdown]
# #### Q75. Using `.loc` with a condition, set `rating` to `"UNRATED"` for all rows where `rating` is missing.

# %%
# Your answer here
df.loc[df['rating'].isna(), 'rating'] = 'UNRATED'

# %%
df.loc[df["rating"] == "UNRATED"]
# Out:
#      show_id     type                                              title  \
# 1513   s2360  TV Show                  Gargantia on the Verdurous Planet
# 2958   s3661  TV Show                                       Little Lunch
# 3042   s3737    Movie                                    Louis C.K. 2017
# 3043   s3738    Movie                              Louis C.K.: Hilarious
# 3044   s3739    Movie               Louis C.K.: Live at the Comedy Store
# 3695   s4324    Movie                               My Honor Was Loyalty
# 6444     s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#              director                                               cast  \
# 1513              NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 2958              NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 3042       Louis C.K.                                         Louis C.K.
# 3043       Louis C.K.                                         Louis C.K.
# 3044       Louis C.K.                                         Louis C.K.
# 3695  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
# 6444              NaN                        Oprah Winfrey, Ava DuVernay
#
#             country date_added  release_year   rating  duration  \
# 1513          Japan   1-Dec-16          2013  UNRATED         1
# 2958      Australia   1-Feb-18          2015  UNRATED         1
# 3042  United States   4-Apr-17          2017  UNRATED        74
# 3043  United States  16-Sep-16          2010  UNRATED        84
# 3044  United States  15-Aug-16          2015  UNRATED        66
# 3695          Italy   1-Mar-17          2015  UNRATED       115
# 6444            NaN  26-Jan-17          2017  UNRATED        37
#
#                                     genres  \
# 1513  Anime Series, International TV Shows
# 2958                 Kids' TV, TV Comedies
# 3042                                Movies
# 3043                                Movies
# 3044                                Movies
# 3695                                Dramas
# 6444                                Movies
#
#                                             description  age_years  is_movie  \
# 1513  After falling through a wormhole, a space-dwel...         13     False
# 2958  Adopting a child's perspective, this show take...         11     False
# 3042  Louis C.K. muses on religion, eternal love, gi...          9      True
# 3043  Emmy-winning comedy writer Louis C.K. brings h...         16      True
# 3044  The comic puts his trademark hilarious/thought...         11      True
# 3695  Amid the chaos and horror of World War II, a c...         11      True
# 6444  Oprah Winfrey sits down with director Ava DuVe...          9      True
#
#       is_recent
# 1513      False
# 2958      False
# 3042      False
# 3043      False
# 3044      False
# 3695      False
# 6444      False

# %% [markdown]
# #### Q76. Replace the value `"United States"` with `"USA"` in the `country` column (hint: `replace`).

# %%
# Your answer here
df['country'] = df['country'].replace('United States', 'USA')

# %%
df.loc[df["country"]=="USA"]
# Out:
#      show_id     type                                      title  \
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 7      s1004    Movie                             Blue Valentine
# 12     s1009    Movie                     Bo Burnham: Make Happy
# 14     s1010    Movie                          Bo Burnham: what.
# 16     s1012    Movie        Bob Lazar: Area 51 & Flying Saucers
# ...      ...      ...                                        ...
# 7776     s99    Movie                              3 Generations
# 7779    s992  TV Show                                  Bloodline
# 7781    s994    Movie                                       Blow
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                             director  \
# 3                       Lev L. Spiro
# 7                   Derek Cianfrance
# 12    Bo Burnham, Christopher Storer
# 14    Bo Burnham, Christopher Storer
# 16     Jeremy Kenyon Lockyer Corbell
# ...                              ...
# 7776                     Gaby Dellal
# 7779                             NaN
# 7781                       Ted Demme
# 7785                     Woody Allen
# 7786                    Alex Lehmann
#
#                                                    cast country date_added  \
# 3     Alan Ritchson, Darin Brooks, James Cade, Rob R...     USA   1-Mar-16
# 7     Ryan Gosling, Michelle Williams, Faith Wladyka...     USA   5-Jul-18
# 12                                           Bo Burnham     USA   3-Jun-16
# 14                                           Bo Burnham     USA   1-Jul-18
# 16                                         Robert Lazar     USA  18-Jun-19
# ...                                                 ...     ...        ...
# 7776  Elle Fanning, Naomi Watts, Susan Sarandon, Tat...     USA  28-Aug-17
# 7779  Kyle Chandler, Ben Mendelsohn, Sissy Spacek, L...     USA  26-May-17
# 7781  Johnny Depp, Penélope Cruz, Franka Potente, Ra...     USA   1-Oct-19
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...     USA   8-Mar-19
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager     USA   6-Dec-16
#
#       release_year rating  duration  \
# 3             2016      R        90
# 7             2010      R       112
# 12            2016  TV-MA        60
# 14            2013  TV-MA        60
# 16            2018  TV-MA        97
# ...            ...    ...       ...
# 7776          2015  PG-13        92
# 7779          2017  TV-MA         3
# 7781          2001      R       123
# 7785          2013  PG-13        98
# 7786          2016  TV-MA        81
#
#                                            genres  \
# 3                                        Comedies
# 7     Dramas, Independent Movies, Romantic Movies
# 12              Music & Musicals, Stand-Up Comedy
# 14                                Stand-Up Comedy
# 16                                  Documentaries
# ...                                           ...
# 7776                         Dramas, LGBTQ Movies
# 7779        TV Dramas, TV Mysteries, TV Thrillers
# 7781                                       Dramas
# 7785         Comedies, Dramas, Independent Movies
# 7786  Dramas, Independent Movies, Romantic Movies
#
#                                             description  age_years  is_movie  \
# 3     New NFL star Thad buys his old teammates' belo...         10      True
# 7     As Cindy and Dean muddle through their languis...         16      True
# 12    Combining his trademark wit and self-deprecati...         10      True
# 14    Left brain and right brain duke it out – and u...         13      True
# 16    Decades ago, Bob Lazar blew the whistle on Are...          8      True
# ...                                                 ...        ...       ...
# 7776  When teenage Ray begins transitioning from fem...         11      True
# 7779  When the black sheep son of a respected family...          9     False
# 7781  Cocaine smuggler George rises from poverty to ...         25      True
# 7785  The high life leads to high anxiety for a fash...         13      True
# 7786  Two former high school sweethearts unexpectedl...         10      True
#
#       is_recent
# 3         False
# 7         False
# 12        False
# 14        False
# 16        False
# ...         ...
# 7776      False
# 7779      False
# 7781      False
# 7785      False
# 7786      False
#
# [2555 rows x 15 columns]

# %% [markdown]
# #### Q77. Convert all titles to UPPERCASE into a new column `title_upper` (hint: `str.upper`).

# %%
# Your answer here
df['title_upper'] = df['title'].str.upper()

# %%
df['title_upper']
# Out:
# 0                                              3%
# 1                                            1920
# 2                                      3 HEROINES
# 3       BLUE MOUNTAIN STATE: THE RISE OF THADLAND
# 4                                  BLUE PLANET II
#                           ...
# 7782                                   BLOWN AWAY
# 7783                                BLUE EXORCIST
# 7784                    BLUE IS THE WARMEST COLOR
# 7785                                 BLUE JASMINE
# 7786                                     BLUE JAY
# Name: title_upper, Length: 7787, dtype: object

# %% [markdown]
# #### Q78. Create a column `title_length` = number of characters in each title (hint: `str.len`).

# %%
# Your answer here
df.loc[:,"title_length"] = df["title"].str.len()

# %%
df.loc[:,"title_length"]
# Out:
# 0        2
# 1        4
# 2       10
# 3       41
# 4       14
#         ..
# 7782    10
# 7783    13
# 7784    25
# 7785    12
# 7786     8
# Name: title_length, Length: 7787, dtype: int64

# %% [markdown]
# #### Q79. Using `.loc`, change the `title` of the row with index label 0 to `"My Favourite Show"`. Display that row to confirm.

# %%
# Your answer here
df.loc[0, 'title'] = 'My Favourite Show'

# %%
df.loc[0]
# Out:
# show_id                                                        s1
# type                                                      TV Show
# title                                           My Favourite Show
# director                                                      NaN
# cast            João Miguel, Bianca Comparato, Michel Gomes, R...
# country                                                    Brazil
# date_added                                              14-Aug-20
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                        4
# genres          International TV Shows, TV Dramas, TV Sci-Fi &...
# description     In a future where the elite inhabit an island ...
# age_years                                                       6
# is_movie                                                    False
# is_recent                                                    True
# title_upper                                                    3%
# title_length                                                    2
# Name: 0, dtype: object

# %% [markdown]
# #### Q80. Add a column `platform` where every row has the value `"Netflix"`.

# %%
# Your answer here
df.loc[:,"platform"] = "Netflix"

# %%
df["platform"]
# Out:
# 0       Netflix
# 1       Netflix
# 2       Netflix
# 3       Netflix
# 4       Netflix
#          ...
# 7782    Netflix
# 7783    Netflix
# 7784    Netflix
# 7785    Netflix
# 7786    Netflix
# Name: platform, Length: 7787, dtype: object

# %% [markdown]
# #### Q81. Delete the column `title_upper` using `drop`.

# %%
df.sample(2)
# Out:
#      show_id     type                 title director  \
# 343    s1307  TV Show  Chef's Table: France      NaN
# 3084   s3775  TV Show             Love Rain      NaN
#
#                                                    cast      country  \
# 343                                                 NaN          NaN
# 3084  Keun-suk Jang, Yoon-ah Im, Shi-hoo Kim, Eun-se...  South Korea
#
#      date_added  release_year rating  duration  \
# 343    2-Sep-16          2016  TV-14         1
# 3084   1-May-18          2012  TV-PG         1
#
#                                                  genres  \
# 343                                          Docuseries
# 3084  International TV Shows, Korean TV Shows, Roman...
#
#                                             description  age_years  is_movie  \
# 343   Sample the bold new flavors of France with che...         10     False
# 3084  A story of two couples' journey of new love, l...         14     False
#
#       is_recent           title_upper  title_length platform
# 343       False  CHEF'S TABLE: FRANCE            20  Netflix
# 3084      False             LOVE RAIN             9  Netflix

# %%
# Your answer here
df.drop(columns="title_upper",inplace=True)

# %%
df.sample(2)
# Out:
#      show_id     type         title    director  \
# 1026   s1922    Movie  Edge of Fear  Bobby Roth
# 591    s1530  TV Show      Creators         NaN
#
#                                                    cast    country date_added  \
# 1026  Shen Lin, Robert Patrick, Zhu Zhu, Jodi Lyn O'...        USA   1-Nov-18
# 591          Fabio Aste, Héctor Segura, Sebastian Rosas  Argentina   1-Nov-18
#
#       release_year rating  duration                               genres  \
# 1026          2018  TV-MA        92        Independent Movies, Thrillers
# 591           2015   TV-Y         2  Kids' TV, Spanish-Language TV Shows
#
#                                             description  age_years  is_movie  \
# 1026  During a wilderness getaway, a gang of sociopa...          8      True
# 591   Two brilliant scientists discover the hidden v...         11     False
#
#       is_recent  title_length platform
# 1026      False            12  Netflix
# 591       False             8  Netflix

# %% [markdown]
# #### Q82. Change `release_year` to type `int32` using `astype`. Check with `dtypes`.

# %%
# Your answer here
df['release_year'] = df['release_year'].astype('int32')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int32
# rating          object
# duration         int64
# genres          object
# description     object
# age_years        int64
# is_movie          bool
# is_recent         bool
# title_length     int64
# platform        object
# dtype: object

# %% [markdown]
# #### Q83. Using `.loc` with a condition, create/overwrite a column `era` = `"old"` for titles before 2010 and `"new"` for 2010 onward (two `.loc` assignments, or `np.where`).

# %%
# Your answer here
df.loc[df['release_year'] < 2010, 'era'] = 'old'
df.loc[df['release_year'] >= 2010, 'era'] = 'new'

# %%
df[['release_year', 'era']].head()
# Out:
#    release_year  era
# 0          2020  new
# 1          2008  old
# 2          2016  new
# 3          2016  new
# 4          2017  new

# %% [markdown]
# #### Q84. Increase `age_years` by 1 for **all** rows in one operation.

# %%
# Your answer here
df['age_years'] = df['age_years']+1

# %%
df.loc[:,"age_years"]
# Out:
# 0        7
# 1       19
# 2       11
# 3       11
# 4       10
#         ..
# 7782     8
# 7783    10
# 7784    14
# 7785    14
# 7786    11
# Name: age_years, Length: 7787, dtype: int64

# %% [markdown]
# #### Q85. Explain in a markdown comment: why is `df.loc[condition, "col"] = value` the SAFE way to update, instead of `df[condition]["col"] = value`? (SettingWithCopyWarning!)

# %%
# Your answer here
# because it does it in a single go in the orginal df.

# %% [markdown]
# ## Section F — GroupBy (Q86–Q105)

# %% [markdown]
# #### Q86. Group by `type` and count the number of titles in each group (`size()`).

# %%
# Your answer here
df.groupby("type").size()
# Out:
# type
# Movie      5377
# TV Show    2410
# dtype: int64

# %% [markdown]
# #### Q87. Group by `rating` and count titles. Which rating is most common?

# %%
# Your answer here
df.groupby('rating').size().sort_values(ascending=False)
# Out:
# rating
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# UNRATED        7
# TV-Y7-FV       6
# UR             5
# NC-17          3
# dtype: int64

# %% [markdown]
# #### Q88. Group by `release_year` and count titles. Which year had the most releases?

# %%
# Your answer here
df.groupby('release_year').size().sort_values(ascending=False)
# Out:
# release_year
# 2018    1121
# 2017    1012
# 2019     996
# 2016     882
# 2020     868
#         ...
# 1925       1
# 1947       1
# 1964       1
# 1966       1
# 1959       1
# Length: 73, dtype: int64

# %% [markdown]
# #### Q89. Group by `type` and find the **minimum** and **maximum** `release_year` for each (hint: `agg(["min","max"])`).

# %%
# Your answer here
df.groupby('type')['release_year'].agg(['min', 'max'])
# Out:
#           min   max
# type
# Movie    1942  2021
# TV Show  1925  2021

# %% [markdown]
# #### Q90. Group by `type` and compute the **average** `age_years`.

# %%
# Your answer here
df.groupby("type")["age_years"].mean()
# Out:
# type
# Movie      14.079970
# TV Show    10.808299
# Name: age_years, dtype: float64

# %% [markdown]
# #### Q91. Group by `country` and count titles — show only the top 10 (sort + head).

# %%
# Your answer here
df.groupby("country").size().sort_values(ascending=False).head(10)
# Out:
# country
# USA               2555
# India              923
# United Kingdom     397
# Japan              226
# South Korea        183
# Canada             177
# Spain              134
# France             115
# Egypt              101
# Turkey             100
# dtype: int64

# %% [markdown]
# #### Q92. Group by `rating` and compute the average `title_length`.

# %%
# Your answer here
df.groupby("rating")["title_length"].mean()
# Out:
# rating
# G           20.820513
# NC-17       17.666667
# NR          16.071429
# PG          18.623482
# PG-13       16.173575
# R           14.703759
# TV-14       16.446919
# TV-G        21.556701
# TV-MA       17.286413
# TV-PG       19.053350
# TV-Y        23.507143
# TV-Y7       24.476015
# TV-Y7-FV    28.000000
# UNRATED     27.285714
# UR          17.600000
# Name: title_length, dtype: float64

# %% [markdown]
# #### Q93. Group by `era` (from Q83) and count Movies vs TV Shows (hint: group by TWO columns).

# %%
# Your answer here
df.groupby(["era", "type"]).size()
# Out:
# era  type
# new  Movie      4374
#      TV Show    2236
# old  Movie      1003
#      TV Show     174
# dtype: int64

# %% [markdown]
# #### Q94. Group by `type` and `rating` together and count. Display the result with `unstack()`.

# %%
# Your answer here
df.groupby(['type', 'rating']).size().unstack()
# Out:
# rating      G  NC-17    NR     PG  PG-13      R   TV-14   TV-G   TV-MA  TV-PG  \
# type
# Movie    39.0    3.0  79.0  247.0  386.0  663.0  1272.0  111.0  1845.0  505.0
# TV Show   NaN    NaN   5.0    NaN    NaN    2.0   659.0   83.0  1018.0  301.0
#
# rating    TV-Y  TV-Y7  TV-Y7-FV  UNRATED   UR
# type
# Movie    117.0   95.0       5.0      5.0  5.0
# TV Show  163.0  176.0       1.0      2.0  NaN

# %% [markdown]
# #### Q95. For Movies only: group by `release_year` and count — how many movies came out each year since 2015? (filter first, then group, then `.tail()`)

# %%
# Your answer here
df.loc[(df['type'] == 'Movie') & (df['release_year'] >= 2015)].groupby('release_year').size().tail()
# Out:
# release_year
# 2017    744
# 2018    734
# 2019    582
# 2020    411
# 2021     12
# dtype: int64

# %% [markdown]
# #### Q96. Group by `country` and compute the average `release_year` — which 5 countries have the 'newest' catalogs on average? (sort descending, head)

# %%
# Your answer here
df.groupby('country')['release_year'].mean().sort_values(ascending=False).head(5)
# Out:
# country
# Canada, United States, Cayman Islands    2021.0
# Australia, New Zealand                   2020.0
# Indonesia, United Kingdom                2020.0
# Brazil, United Kingdom                   2020.0
# Belgium, Netherlands                     2020.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q97. Use `value_counts()` on `genres` — why does this NOT give clean genre counts? Explain in a comment (hint: multiple genres in one cell).

# %%
# Your answer here
df['genres'].value_counts()
# Out:
# genres
# Documentaries                                                                      334
# Stand-Up Comedy                                                                    321
# Dramas, International Movies                                                       320
# Comedies, Dramas, International Movies                                             243
# Dramas, Independent Movies, International Movies                                   215
#                                                                                   ...
# Kids' TV, Reality TV, Science & Nature TV                                            1
# International TV Shows, Spanish-Language TV Shows, Stand-Up Comedy & Talk Shows      1
# Sci-Fi & Fantasy                                                                     1
# International TV Shows, TV Action & Adventure, TV Horror                             1
# Stand-Up Comedy & Talk Shows, TV Mysteries, TV Sci-Fi & Fantasy                      1
# Name: count, Length: 492, dtype: int64

# %%
#because eutai cell has multiple valus too so it does not count it as seperate

# %% [markdown]
# #### Q98. Group by `is_recent` and count — how many recent vs old titles?

# %%
# Your answer here
df.groupby('is_recent').size()
# Out:
# is_recent
# False    6888
# True      899
# dtype: int64

# %% [markdown]
# #### Q99. Group by `type` and use `.agg()` with a dictionary: count of `title` and mean of `age_years` in ONE command.

# %%
# Your answer here
df.groupby('type').agg(title_count=('title', 'count'), avg_age_years=('age_years', 'mean'))
# Out:
#          title_count  avg_age_years
# type
# Movie           5377      14.079970
# TV Show         2410      10.808299

# %% [markdown]
# #### Q100. Group by `rating` and show the **number of unique countries** per rating (hint: `nunique`).

# %%
# Your answer here
df.groupby("rating")["country"].nunique()
# Out:
# rating
# G            11
# NC-17         3
# NR           31
# PG           61
# PG-13       101
# R           157
# TV-14       166
# TV-G         40
# TV-MA       290
# TV-PG        99
# TV-Y         51
# TV-Y7        56
# TV-Y7-FV      5
# UNRATED       4
# UR            5
# Name: country, dtype: int64

# %% [markdown]
# #### Q101. Using `groupby` + `head(1)`, show the FIRST title (by current order) in each `type` group.

# %%
# Your answer here
df.groupby("type").head(1)
# Out:
#   show_id     type              title      director  \
# 0      s1  TV Show  My Favourite Show           NaN
# 1     s10    Movie               1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#    release_year rating  duration  \
# 0          2020  TV-MA         4
# 1          2008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description  age_years  is_movie  \
# 0  In a future where the elite inhabit an island ...          7     False
# 1  An architect and his wife move into a castle t...         19      True
#
#    is_recent  title_length platform  era
# 0       True             2  Netflix  new
# 1      False             4  Netflix  old

# %% [markdown]
# #### Q102. Group by `release_year` and count, then plot it with `.plot()` (line chart). What trend do you see?

# %%
# Your answer here
df.groupby("release_year").size().plot()
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# #### Q103. Group by `year_added`-style logic isn't possible yet — `date_added` is still text! Group by the **first 4 characters trick is wrong**. Explain in a comment why we need Section G (Cleaning) before we can group by the year a title was ADDED.

# %%
# Your answer here
# date_added is text so convert it to a date first before getting the year

# %% [markdown]
# #### Q104. Group by `type` and compute the **median** `release_year`.

# %%
# Your answer here
df.groupby("type")["release_year"].median()
# Out:
# type
# Movie      2016.0
# TV Show    2018.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q105. Challenge: for each `rating`, what percentage of titles are Movies? (hint: group by rating, compute the mean of `is_movie`, multiply by 100)

# %%
# Your answer here
df.groupby("rating")["is_movie"].mean() * 100
# Out:
# rating
# G           100.000000
# NC-17       100.000000
# NR           94.047619
# PG          100.000000
# PG-13       100.000000
# R            99.699248
# TV-14        65.872605
# TV-G         57.216495
# TV-MA        64.442892
# TV-PG        62.655087
# TV-Y         41.785714
# TV-Y7        35.055351
# TV-Y7-FV     83.333333
# UNRATED      71.428571
# UR          100.000000
# Name: is_movie, dtype: float64

# %% [markdown]
# ## Section G — Cleaning (Q106–Q125)

# %% [markdown]
# #### Q106. Re-check missing values per column (things changed since Section A!).

# %%
# Your answer here
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %% [markdown]
# #### Q107. Fill missing `director` values with `"Unknown"`.

# %%
# Your answer here
df.loc[df["director"].isna(),"director"]="Unknown"

# %%
df.loc[df["director"]=="Unknown"].sample(2)
# Out:
#      show_id     type         title director  \
# 2592   s3331  TV Show      Kazoops!  Unknown
# 780    s1700  TV Show  Demon's Path  Unknown
#
#                                                    cast    country date_added  \
# 2592  Reece Pockney, Scott Langley, Alex Babic, Gemm...  Australia   5-May-17
# 780   Wai Ai, Jim Chim Sui Man, Kwok-Pong Chan, Feli...        NaN  22-Dec-18
#
#       release_year rating  duration  \
# 2592          2017   TV-Y         3
# 780           2018  TV-14         1
#
#                                                  genres  \
# 2592                                           Kids' TV
# 780   Crime TV Shows, International TV Shows, TV Dramas
#
#                                             description
# 2592  Music meets imagination in this inventive anim...
# 780   To catch three criminal masterminds, a group o...

# %% [markdown]
# #### Q108. Fill missing `cast` values with `"Unknown"`.

# %%
# Your answer here
df.loc[df["cast"].isna(),"cast"]="Unknown"

# %%
df.loc[df["cast"]=="Unknown"].sample(1)
# Out:
#      show_id   type                                              title  \
# 2894   s3603  Movie  Les Bleus - Une autre histoire de France, 1996...
#
#                                          director     cast country date_added  \
# 2894  Pascal Blanchard, Sonia Dauger, David Dietz  Unknown  France  15-Mar-17
#
#       release_year rating  duration  \
# 2894          2016  TV-MA       103
#
#                                                  genres  \
# 2894  Documentaries, International Movies, Sports Mo...
#
#                                             description
# 2894  This documentary charts 20 years of the French...

# %% [markdown]
# #### Q109. Fill missing `country` values with the **most common** country (hint: `mode()[0]`).

# %%
# Your answer here
common=df.loc[df["country"].isna(),"country"]=df["country"].mode()[0]

# %%
common
# Out:
# 'United States'

# %% [markdown]
# #### Q110. Count the rows where `date_added` is missing, then drop those rows.

# %%
# Your answer here
df["date_added"].isna().sum()
# Out:
# np.int64(10)

# %%
# Your answer here
#subset ley chai only that column ko remove hunxa
df = df.dropna(subset=["date_added"])

# %% [markdown]
# for missing in rating

# %%
df["rating"] = df["rating"].fillna("UNRATED")
# Out:
# /tmp/ipykernel_11190/3988448435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rating"] = df["rating"].fillna("UNRATED")

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# genres          0
# description     0
# dtype: int64

# %% [markdown]
# #### Q111. `date_added` has extra spaces in some rows — strip them (hint: `str.strip`).

# %%
df['date_added'] = df['date_added'].str.strip()
# Out:
# /tmp/ipykernel_11190/1220781913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added'] = df['date_added'].str.strip()

# %% [markdown]
# #### Q112. Convert `date_added` to datetime with `pd.to_datetime`. Check the dtype after.

# %%
# Your answer here
df['date_added'] = pd.to_datetime(df['date_added'], format='mixed')
# Out:
# /tmp/ipykernel_11190/4248998911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added'] = pd.to_datetime(df['date_added'], format='mixed')

# %%
df['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# #### Q113. NOW create `year_added` = `.dt.year` and `month_added` = `.dt.month_name()`.

# %%
# Your answer here
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month_name()
# Out:
# /tmp/ipykernel_11190/3374714695.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_added'] = df['date_added'].dt.year
# /tmp/ipykernel_11190/3374714695.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_added'] = df['date_added'].dt.month_name()

# %% [markdown]
# #### Q114. Group by `year_added` and count — which year did Netflix add the most content? (This is the question F103 could not answer!)

# %%
# Your answer here
df.groupby('year_added').size().sort_values(ascending=False)
# Out:
# year_added
# 2019    2153
# 2020    2009
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# dtype: int64

# %% [markdown]
# #### Q115. Group by `month_added` and count — which month is most popular for adding content?

# %%
# Your answer here
df.groupby('month_added').size().sort_values(ascending=False)
# Out:
# month_added
# December     833
# October      785
# January      757
# November     738
# March        669
# September    619
# August       618
# April        601
# July         600
# May          543
# June         542
# February     472
# dtype: int64

# %% [markdown]
# #### Q116. Look at the `duration` column with `unique()` (first 20 values) — what TWO different formats do you see?

# %%
# Your answer here
df['duration'].unique()[:20]
# Out:
# array([  4, 143, 124,  90,   1,  94, 112, 129,  85, 108,  60, 164,  97,
#         47,  99,  83, 168, 116,  53, 106])

# %% [markdown]
# #### Q117. Extract the number from `duration` into a new column `duration_int` (hint: `str.extract(r"(\\d+)")` then `astype(float)`).

# %%
# Your answer here
df['duration_int'] = df['duration'].astype(float)
# Out:
# /tmp/ipykernel_11190/1952710937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration_int'] = df['duration'].astype(float)

# %% [markdown]
# #### Q118. For Movies only: what is the average, minimum, and maximum duration in minutes?

# %%
# Your answer here
df.loc[df['type'] == 'Movie', 'duration_int'].agg(['mean', 'min', 'max'])
# Out:
# mean     99.307978
# min       3.000000
# max     312.000000
# Name: duration_int, dtype: float64

# %% [markdown]
# #### Q119. For TV Shows only: how many have more than 5 seasons? Show their titles.

# %%
# Your answer here
df.loc[(df['type'] == 'TV Show') & (df['duration_int'] > 5), 'title']
# Out:
# 31                  BoJack Horseman
# 184                     Cable Girls
# 204                Call the Midwife
# 337                          Cheers
# 341                    Chef's Table
#                    ...
# 7037                   Under Arrest
# 7161    Voltron: Legendary Defender
# 7247                          Weeds
# 7262                      Wentworth
# 7265             West Coast Customs
# Name: title, Length: 88, dtype: object

# %% [markdown]
# #### Q120. Check duplicated **titles** (not full rows): are there any titles that appear more than once? Display them.

# %%
# Your answer here
df['title'].duplicated().sum()
df.loc[df['title'].duplicated(keep=False)].sort_values('title')
# Out:
# np.int64(0)

# %%
df.loc[df['title'].duplicated(keep=False)].sort_values('title')
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description, year_added, month_added, duration_int]
# Index: []

# %% [markdown]
# #### Q121. Are those duplicated titles real duplicates or different shows? Inspect a few with `.loc` and explain in a comment.

# %%
# Your answer here
dup_titles = df.loc[df['title'].duplicated(keep=False), 'title'].unique()[:5]

# %%
df.loc[df['title'].isin(dup_titles)].sort_values('title')
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description, year_added, month_added, duration_int]
# Index: []

# %% [markdown]
# #### Q122. The `rating` column contains some WRONG values that are actually durations (like `"74 min"`) — find them (hint: `str.contains("min", na=False)`).

# %%
# Your answer here
df.loc[df['rating'].astype(str).str.contains('min', na=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description, year_added, month_added, duration_int]
# Index: []

# %% [markdown]
# #### Q123. Fix those wrong rating rows: set their `rating` to `"UNRATED"` using `.loc`.

# %%
# Your answer here
df.loc[df['rating'].astype(str).str.contains('min', na=False), 'rating'] = 'UNRATED'

# %% [markdown]
# #### Q124. Final check: run `info()` and `isna().sum()` — is the dataset clean now? Summarize what you fixed in a comment.

# %%
# Your answer here
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7777 entries, 0 to 7786
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7777 non-null   object
#  1   type          7777 non-null   object
#  2   title         7777 non-null   object
#  3   director      7777 non-null   object
#  4   cast          7777 non-null   object
#  5   country       7777 non-null   object
#  6   date_added    7777 non-null   datetime64[ns]
#  7   release_year  7777 non-null   int64
#  8   rating        7777 non-null   object
#  9   duration      7777 non-null   int64
#  10  genres        7777 non-null   object
#  11  description   7777 non-null   object
#  12  year_added    7777 non-null   int32
#  13  month_added   7777 non-null   object
#  14  duration_int  7777 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(2), object(10)
# memory usage: 941.7+ KB
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# genres          0
# description     0
# year_added      0
# month_added     0
# duration_int    0
# dtype: int64

# %% [markdown]
# # - director and cast ko missing values filled with Unknown.
# # - country ko missing values chai filled with the most common country mode()
# # - date_added ko first ma missing row dropp and whitespace and converted to datetime
# # - rating ko missing values ra wrong duration vako is  set to "UNRATED"
# # - added helper columns: age_years, is_movie, is_recent, era, title_length,
# #   year_added, month_added, duration_int and platform

# %% [markdown]
# #### Q125. Save your cleaned DataFrame to a new file `netflix_clean.csv` (without the index). This file is your submission proof!

# %%
# Your answer here
df.to_csv('netflix_clean.csv', index=False)

# %% [markdown]
# ---
# ## Submission
# - Answer **all 125 questions** — partial answers get partial marks
# - Run All must work top to bottom without errors (−5 marks if it crashes)
# - Submit BOTH files: `YourName_workbook.ipynb` and `netflix_clean.csv`
